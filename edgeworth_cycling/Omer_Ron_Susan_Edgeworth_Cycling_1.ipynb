# %% [markdown]
# ## Edgeworth Cycling Multi Agent Environment.

# %%
# !pip install ray[rllib]==2.7.0
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting ray[rllib]==2.7.0
#   Downloading ray-2.7.0-cp310-cp310-manylinux2014_x86_64.whl (62.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 MB 14.9 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: aiosignal in /home/fitz/.local/lib/python3.10/site-packages (from ray[rllib]==2.7.0) (1.3.1)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /home/fitz/.local/lib/python3.10/site-packages (from ray[rllib]==2.7.0) (1.0.8)
# Requirement already satisfied: click>=7.0 in /usr/lib/python3/dist-packages (from ray[rllib]==2.7.0) (8.0.3)
# Requirement already satisfied: requests in /home/fitz/.local/lib/python3.10/site-packages (from ray[rllib]==2.7.0) (2.31.0)
# Requirement already satisfied: numpy>=1.19.3 in /home/fitz/.local/lib/python3.10/site-packages (from ray[rllib]==2.7.0) (1.24.3)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /home/fitz/.local/lib/python3.10/site-packages (from ray[rllib]==2.7.0) (4.25.3)
# Requirement already satisfied: packaging in /home/fitz/.local/lib/python3.10/site-packages (from ray[rllib]==2.7.0) (24.0)
# Requirement already satisfied: frozenlist in /home/fitz/.local/lib/python3.10/site-packages (from ray[rllib]==2.7.0) (1.4.1)
# Requirement already satisfied: filelock in /home/fitz/.local/lib/python3.10/site-packages (from ray[rllib]==2.7.0) (3.13.4)
# Requirement already satisfied: jsonschema in /home/fitz/.local/lib/python3.10/site-packages (from ray[rllib]==2.7.0) (4.21.1)
# Requirement already satisfied: pyyaml in /usr/lib/python3/dist-packages (from ray[rllib]==2.7.0) (5.4.1)
# Requirement already satisfied: fsspec in /home/fitz/.local/lib/python3.10/site-packages (from ray[rllib]==2.7.0) (2024.2.0)
# Requirement already satisfied: gymnasium==0.28.1 in /home/fitz/.local/lib/python3.10/site-packages (from ray[rllib]==2.7.0) (0.28.1)
# Requirement already satisfied: typer in /home/fitz/.local/lib/python3.10/site-packages (from ray[rllib]==2.7.0) (0.12.3)
# Requirement already satisfied: dm-tree in /home/fitz/.local/lib/python3.10/site-packages (from ray[rllib]==2.7.0) (0.1.8)
# Requirement already satisfied: tensorboardX>=1.9 in /home/fitz/.local/lib/python3.10/site-packages (from ray[rllib]==2.7.0) (2.6.2.2)
# Requirement already satisfied: lz4 in /home/fitz/.local/lib/python3.10/site-packages (from ray[rllib]==2.7.0) (4.3.3)
# Requirement already satisfied: pandas in /home/fitz/.local/lib/python3.10/site-packages (from ray[rllib]==2.7.0) (2.2.2)
# Requirement already satisfied: rich in /home/fitz/.local/lib/python3.10/site-packages (from ray[rllib]==2.7.0) (13.7.1)
# Requirement already satisfied: scipy in /home/fitz/.local/lib/python3.10/site-packages (from ray[rllib]==2.7.0) (1.13.0)
# Requirement already satisfied: scikit-image in /home/fitz/.local/lib/python3.10/site-packages (from ray[rllib]==2.7.0) (0.23.2)
# Requirement already satisfied: pyarrow>=6.0.1 in /home/fitz/.local/lib/python3.10/site-packages (from ray[rllib]==2.7.0) (15.0.2)
# Requirement already satisfied: jax-jumpy>=1.0.0 in /home/fitz/.local/lib/python3.10/site-packages (from gymnasium==0.28.1->ray[rllib]==2.7.0) (1.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /home/fitz/.local/lib/python3.10/site-packages (from gymnasium==0.28.1->ray[rllib]==2.7.0) (4.11.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/fitz/.local/lib/python3.10/site-packages (from gymnasium==0.28.1->ray[rllib]==2.7.0) (3.0.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /home/fitz/.local/lib/python3.10/site-packages (from gymnasium==0.28.1->ray[rllib]==2.7.0) (0.0.4)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/fitz/.local/lib/python3.10/site-packages (from jsonschema->ray[rllib]==2.7.0) (2023.12.1)
# Requirement already satisfied: attrs>=22.2.0 in /home/fitz/.local/lib/python3.10/site-packages (from jsonschema->ray[rllib]==2.7.0) (23.2.0)
# Requirement already satisfied: referencing>=0.28.4 in /home/fitz/.local/lib/python3.10/site-packages (from jsonschema->ray[rllib]==2.7.0) (0.34.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/fitz/.local/lib/python3.10/site-packages (from jsonschema->ray[rllib]==2.7.0) (0.18.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/fitz/.local/lib/python3.10/site-packages (from pandas->ray[rllib]==2.7.0) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /home/fitz/.local/lib/python3.10/site-packages (from pandas->ray[rllib]==2.7.0) (2024.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas->ray[rllib]==2.7.0) (2022.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests->ray[rllib]==2.7.0) (2020.6.20)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests->ray[rllib]==2.7.0) (3.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/fitz/.local/lib/python3.10/site-packages (from requests->ray[rllib]==2.7.0) (2.2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/fitz/.local/lib/python3.10/site-packages (from requests->ray[rllib]==2.7.0) (3.3.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/fitz/.local/lib/python3.10/site-packages (from rich->ray[rllib]==2.7.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/fitz/.local/lib/python3.10/site-packages (from rich->ray[rllib]==2.7.0) (2.17.2)
# Requirement already satisfied: pillow>=9.1 in /home/fitz/.local/lib/python3.10/site-packages (from scikit-image->ray[rllib]==2.7.0) (10.3.0)
# Requirement already satisfied: lazy-loader>=0.4 in /home/fitz/.local/lib/python3.10/site-packages (from scikit-image->ray[rllib]==2.7.0) (0.4)
# Requirement already satisfied: networkx>=2.8 in /home/fitz/.local/lib/python3.10/site-packages (from scikit-image->ray[rllib]==2.7.0) (3.3)
# Requirement already satisfied: imageio>=2.33 in /home/fitz/.local/lib/python3.10/site-packages (from scikit-image->ray[rllib]==2.7.0) (2.34.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /home/fitz/.local/lib/python3.10/site-packages (from scikit-image->ray[rllib]==2.7.0) (2024.4.18)
# Requirement already satisfied: shellingham>=1.3.0 in /home/fitz/.local/lib/python3.10/site-packages (from typer->ray[rllib]==2.7.0) (1.5.4)
# Requirement already satisfied: mdurl~=0.1 in /home/fitz/.local/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->ray[rllib]==2.7.0) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas->ray[rllib]==2.7.0) (1.16.0)
# Installing collected packages: ray
#   Attempting uninstall: ray
#     Found existing installation: ray 2.11.0
#     Uninstalling ray-2.11.0:
#       Successfully uninstalled ray-2.11.0
# Successfully installed ray-2.7.0

# %%
import random
import gymnasium as gym
from gymnasium import spaces, vector
import numpy as np
from ray import tune
from scipy.stats import binom, nbinom, beta, poisson, gamma, norm, geom
from ray.rllib.env.multi_agent_env import MultiAgentEnv
from functools import partial
# Out:
# 2024-05-12 20:54:07,567	WARNING deprecation.py:50 -- DeprecationWarning: `DirectStepOptimizer` has been deprecated. This will raise an error in the future!

# %%
'''
This code is a slightly simplified version of the environment found in the paper:
Oligopoly competition in fixed cost environments
https://www.sciencedirect.com/science/article/pii/S0167718703001577
'''

import numpy as np
import gymnasium as gym
from functools import partial
from gymnasium import spaces
from ray.rllib.env.multi_agent_env import MultiAgentEnv

def calculate_sales(offers, intercept, slope):
    total_sold = 0
    sales = {}

    offers = sorted([(offer[0], offer[1], aid) for aid, offer in offers.items()])
    i = 0
    while i < len(offers):
        # Find all offers with the same price at the current index
        current_price = offers[i][0]
        next_i = i+1
        while next_i < len(offers) and offers[next_i][0] == current_price:
            next_i += 1
        n_equal = next_i - i

        # Calculate remaining demand at this price
        demand = (intercept - current_price) / slope - total_sold
        demand = max(0,demand)
        for k in range(i, next_i):
            demand_share = demand / n_equal

            quantity = offers[k][1]
            firm_id = offers[k][2]
            actual_sold = min(quantity, demand_share)
            sales[firm_id] = actual_sold
            total_sold += actual_sold
            demand -= actual_sold

            n_equal -= 1
        i = next_i
    return sales


class OligopolyMarket(MultiAgentEnv):
    def __init__(self, seed=None):
        super().__init__()
        self.n_firms = 5
        self._agent_ids = [f'firm_{i}' for i in range(self.n_firms)]

        self.history_length = 5
        self.price_history = []
        self.intercept = 17
        self.slope = 0.01
        self.n_periods = 80

        # Actions are tuples of (price, quantity) for each firm
        self.ind_action_space = spaces.Tuple((
            spaces.Box(low=0,high=self.intercept),
            spaces.Box(low=0,high=300)
        ))

        self.ind_observation_space = spaces.Box(
            low=0,
            high=self.intercept,
            shape=(self.history_length,)
        )
        self.action_space = gym.spaces.Dict(self.make_agent_dictionary(self.ind_action_space))
        self.observation_space = gym.spaces.Dict(self.make_agent_dictionary(self.ind_observation_space))

        self.costs = [4.0]*100 + [4.5]*100 + [5.0]*100
        self.sales_calc = partial(calculate_sales, intercept=self.intercept, slope=self.slope)

    def make_agent_dictionary(self, res):
        return {agent_id: res for agent_id in self._agent_ids}

    def get_observation(self):
        price_history = list(reversed(self.price_history[-self.history_length:]))
        price_history = np.array(price_history, dtype=np.float32)
        return self.make_agent_dictionary(price_history)

    def reset(self, seed=None, options=None):
        self.price_history = [0]*self.history_length
        self.period = 0
        return self.get_observation(), {}

    def step(self, actions):
        self.period += 1
        prices = {aid: np.round(action[0][0],2) for aid,action in actions.items()}
        quantities = {aid: action[1][0] for aid,action in actions.items()}
        offers = {aid: (prices[aid],quantities[aid]) for aid in self._agent_ids}
        sales = self.sales_calc(offers)
        profits = {}
        for aid in self._agent_ids:
            q = sales[aid]
            p = prices[aid]
            costs = sum(self.costs[:int(q)])
            # Add costs in event they sold fraction of a unit
            if q < len(self.costs):
                costs += (q - int(q))*self.costs[int(q)]
            profits[aid] = p*q - costs
        tot_sales = sum(sales.values())
        if tot_sales > 0:
            avg_price = sum(sales[aid]*prices[aid] for aid in sales.keys())/sum(sales.values())
        else:
            avg_price = self.intercept
        self.price_history.append(avg_price)

        rewards = self.get_rewards(profits)
        done = self.period == self.n_periods
        dones = self.make_agent_dictionary(done)
        dones['__all__'] = done
        truncated = dones
        info = {}
        return self.get_observation(), rewards, dones, truncated, info

    def get_evaluation_reward(self, profits):
        return profits

    def get_rewards(self, profits):
        return self.get_evaluation_reward(profits)

# %%
# Test Code

offers = {
    'firm1': (12, 50),
    'firm2': (11, 400),
    'firm3': (13, 100)
}

intercept = 17
slope = 0.01

result = calculate_sales(offers, intercept, slope)
print(result)
# Out:
# {'firm2': 400, 'firm1': 50, 'firm3': 0.0}

# %%
env = OligopolyMarket()

# %%
env.observation_space.sample()
# Out:
# OrderedDict([('firm_0',
#               array([ 0.45141014,  0.16443944, 14.493833  , 16.606543  ,  1.2780769 ],
#                     dtype=float32)),
#              ('firm_1',
#               array([12.923358, 12.776037, 13.560927, 10.538004, 13.373651],
#                     dtype=float32)),
#              ('firm_2',
#               array([ 0.48759073, 14.794913  , 14.728542  , 16.857182  ,  9.074473  ],
#                     dtype=float32)),
#              ('firm_3',
#               array([ 3.0088277,  8.1761265,  3.7867527, 11.710337 ,  9.020187 ],
#                     dtype=float32)),
#              ('firm_4',
#               array([11.312584 , 11.576518 ,  4.051092 ,  3.8614366,  4.92761  ],
#                     dtype=float32))])

# %%
env.reset()
# Out:
# ({'firm_0': array([0., 0., 0., 0., 0.], dtype=float32),
#   'firm_1': array([0., 0., 0., 0., 0.], dtype=float32),
#   'firm_2': array([0., 0., 0., 0., 0.], dtype=float32),
#   'firm_3': array([0., 0., 0., 0., 0.], dtype=float32),
#   'firm_4': array([0., 0., 0., 0., 0.], dtype=float32)},
#  {})

# %%
env.observation_space.contains(env.reset()[0])
# Out:
# True

# %%
obs, _,_,_,_ = env.step(env.action_space.sample())

# %%
env.observation_space.contains(obs)
# Out:
# True

# %%
env.reset()
done = False
rewards = []
while not done:
    obs, reward, done, _, _ = env.step(env.action_space.sample())
    done = done['__all__']
    rewards.append(reward)

# %%
import ray
from ray import tune, air
from ray.rllib.algorithms.ppo import PPOConfig
from functools import partial

# %%
if ray.is_initialized():
  ray.shutdown()
ray.init(num_cpus=4)
# Out:
# 2024-05-12 20:54:19,568	INFO worker.py:1642 -- Started a local Ray instance.
# RayContext(dashboard_url='', python_version='3.10.12', ray_version='2.7.0', ray_commit='b4bba4717f5ba04ee25580fe8f88eed63ef0c5dc', protocol_version=None)
# (pid=8832) DeprecationWarning: `DirectStepOptimizer` has been deprecated. This will raise an error in the future!
# (PPO pid=8832) 2024-05-12 20:54:34,320	WARNING algorithm_config.py:2578 -- Setting `exploration_config={}` because you set `_enable_rl_module_api=True`. When RLModule API are enabled, exploration_config can not be set. If you want to implement custom exploration behaviour, please modify the `forward_exploration` method of the RLModule at hand. On configs that have a default exploration config, this must be done with `config.exploration_config={}`.
# (PPO pid=8832) 2024-05-12 20:54:34,321	WARNING algorithm_config.py:672 -- Cannot create PPOConfig from given `config_dict`! Property __stdout_file__ not supported.
# (RolloutWorker pid=8865) 2024-05-12 20:54:37,988	WARNING deprecation.py:50 -- DeprecationWarning: `ValueNetworkMixin` has been deprecated. This will raise an error in the future!
# (RolloutWorker pid=8865) 2024-05-12 20:54:37,988	WARNING deprecation.py:50 -- DeprecationWarning: `LearningRateSchedule` has been deprecated. This will raise an error in the future!
# (RolloutWorker pid=8865) 2024-05-12 20:54:37,988	WARNING deprecation.py:50 -- DeprecationWarning: `EntropyCoeffSchedule` has been deprecated. This will raise an error in the future!
# (RolloutWorker pid=8865) 2024-05-12 20:54:37,988	WARNING deprecation.py:50 -- DeprecationWarning: `KLCoeffMixin` has been deprecated. This will raise an error in the future!

# %% [markdown]
# ## Asymetric Policys

# %%
agent_ids = OligopolyMarket()._agent_ids
sym_policies = {agent_id: f"policy_firm_0" for agent_id in agent_ids}  # Symmetric
asym_policies = {agent_id: f"policy_{agent_id}" for agent_id in agent_ids}  # Asymmetric
exploit_policies = asym_policies.copy()
#exploit_policies[list(exploit_policies.keys())[-1]] = "policy_firm_ex"

# %%
asym_policies
# Out:
# {'firm_0': 'policy_firm_0',
#  'firm_1': 'policy_firm_1',
#  'firm_2': 'policy_firm_2',
#  'firm_3': 'policy_firm_3',
#  'firm_4': 'policy_firm_4'}

# %%
def policy_mapping_fn(agent_id, episode, worker, *, policies=None, **kwargs):
    return policies[agent_id]


policies = asym_policies
policy_mapping = partial(policy_mapping_fn, policies=policies)

config = (
        PPOConfig()
        .environment(OligopolyMarket)
        .framework('torch')
        .training(train_batch_size=1024, gamma=0.99)
        .resources(num_gpus=0)
        .rollouts(num_rollout_workers=3)
        .multi_agent(policies=list(policies.values()),
                     policy_mapping_fn=policy_mapping)
    )

stop = {"timesteps_total": 100000}

# THE WAY OF CODING IS A BIT DIFFERENT HERE FROM THE SINGLE AGENT ONE.
tuner = tune.Tuner(
        "PPO",
        param_space=config.to_dict(),
        run_config=air.RunConfig(stop=stop),
    )


tuner.fit()
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2024-05-12 20:55:26</td></tr>
# <tr><td>Running for: </td><td>00:00:55.64        </td></tr>
# <tr><td>Memory:      </td><td>7.9/125.7 GiB      </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Logical resource usage: 4.0/4 CPUs, 0/1 GPUs (0.0/1.0 accelerator_type:G)
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name                     </th><th>status  </th><th>loc               </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_OligopolyMarket_807e6_00000</td><td>RUNNING </td><td>192.168.1.114:8832</td><td style="text-align: right;">     5</td><td style="text-align: right;">         42.0197</td><td style="text-align: right;">5120</td><td style="text-align: right;">   49988</td><td style="text-align: right;">             91295.6</td><td style="text-align: right;">             6751.18</td><td style="text-align: right;">                80</td></tr>
# </tbody>
# </table>
#   </div>
# </div>
# <style>
# .tuneStatus {
#   color: var(--jp-ui-font-color1);
# }
# .tuneStatus .systemInfo {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus td {
#   white-space: nowrap;
# }
# .tuneStatus .trialStatus {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus h3 {
#   font-weight: bold;
# }
# .tuneStatus .hDivider {
#   border-bottom-width: var(--jp-border-width);
#   border-bottom-color: var(--jp-border-color0);
#   border-bottom-style: solid;
# }
# .tuneStatus .vDivider {
#   border-left-width: var(--jp-border-width);
#   border-left-color: var(--jp-border-color0);
#   border-left-style: solid;
#   margin: 0.5em 1em 0.5em 1em;
# }
# </style>
# 2024-05-12 20:54:30,658	WARNING algorithm_config.py:2578 -- Setting `exploration_config={}` because you set `_enable_rl_module_api=True`. When RLModule API are enabled, exploration_config can not be set. If you want to implement custom exploration behaviour, please modify the `forward_exploration` method of the RLModule at hand. On configs that have a default exploration config, this must be done with `config.exploration_config={}`.

# %% [markdown]
#  **path=/root/ray_results/PPO_2024-05-11_13-40-02/PPO_OligopolyMarket_f84b3_00000_0_2024-05-11_13-40-03/checkpoint_000000**

# %%
from ray.rllib.algorithms.algorithm import Algorithm

# %%
algo_asym = Algorithm.from_checkpoint("/root/ray_results/PPO_2024-05-11_13-40-02/PPO_OligopolyMarket_f84b3_00000_0_2024-05-11_13-40-03/checkpoint_000000")
# Out:
# 2024-05-11 14:31:41,166	WARNING algorithm_config.py:2578 -- Setting `exploration_config={}` because you set `_enable_rl_module_api=True`. When RLModule API are enabled, exploration_config can not be set. If you want to implement custom exploration behaviour, please modify the `forward_exploration` method of the RLModule at hand. On configs that have a default exploration config, this must be done with `config.exploration_config={}`.
# 2024-05-11 14:31:41,173	WARNING algorithm_config.py:672 -- Cannot create PPOConfig from given `config_dict`! Property __stdout_file__ not supported.
# 2024-05-11 14:31:41,185	WARNING algorithm_config.py:2578 -- Setting `exploration_config={}` because you set `_enable_rl_module_api=True`. When RLModule API are enabled, exploration_config can not be set. If you want to implement custom exploration behaviour, please modify the `forward_exploration` method of the RLModule at hand. On configs that have a default exploration config, this must be done with `config.exploration_config={}`.
# /usr/local/lib/python3.10/dist-packages/ray/rllib/algorithms/algorithm.py:484: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# `UnifiedLogger` will be removed in Ray 2.7.
#   return UnifiedLogger(config, logdir, loggers=None)
# /usr/local/lib/python3.10/dist-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `JsonLogger interface is deprecated in favor of the `ray.tune.json.JsonLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /usr/local/lib/python3.10/dist-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `CSVLogger interface is deprecated in favor of the `ray.tune.csv.CSVLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /usr/local/lib/python3.10/dist-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `TBXLogger interface is deprecated in favor of the `ray.tune.tensorboardx.TBXLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# (pid=120909) /usr/local/lib/python3.10/dist-packages/tensorflow_probability/python/__init__.py:57: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
# (pid=120909)   if (distutils.version.LooseVersion(tf.__version__) <
# (pid=120909) DeprecationWarning: `DirectStepOptimizer` has been deprecated. This will raise an error in the future!
# (RolloutWorker pid=120909) /usr/local/lib/python3.10/dist-packages/ray/rllib/models/catalog.py:786: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
# (RolloutWorker pid=120909)   prep = cls(observation_space, options)
# (RolloutWorker pid=120909) 2024-05-11 14:32:02,222	WARNING algorithm_config.py:2578 -- Setting `exploration_config={}` because you set `_enable_rl_module_api=True`. When RLModule API are enabled, exploration_config can not be set. If you want to implement custom exploration behaviour, please modify the `forward_exploration` method of the RLModule at hand. On configs that have a default exploration config, this must be done with `config.exploration_config={}`.
# (RolloutWorker pid=120909) /usr/local/lib/python3.10/dist-packages/ray/rllib/policy/policy.py:1732: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
# (RolloutWorker pid=120909)   _, shape = ModelCatalog.get_action_shape(
# (RolloutWorker pid=120909) 2024-05-11 14:32:02,313	WARNING algorithm_config.py:2578 -- Setting `exploration_config={}` because you set `_enable_rl_module_api=True`. When RLModule API are enabled, exploration_config can not be set. If you want to implement custom exploration behaviour, please modify the `forward_exploration` method of the RLModule at hand. On configs that have a default exploration config, this must be done with `config.exploration_config={}`.
# (RolloutWorker pid=120909) 2024-05-11 14:32:02,371	WARNING algorithm_config.py:2578 -- Setting `exploration_config={}` because you set `_enable_rl_module_api=True`. When RLModule API are enabled, exploration_config can not be set. If you want to implement custom exploration behaviour, please modify the `forward_exploration` method of the RLModule at hand. On configs that have a default exploration config, this must be done with `config.exploration_config={}`.
# (RolloutWorker pid=120909) 2024-05-11 14:32:02,429	WARNING algorithm_config.py:2578 -- Setting `exploration_config={}` because you set `_enable_rl_module_api=True`. When RLModule API are enabled, exploration_config can not be set. If you want to implement custom exploration behaviour, please modify the `forward_exploration` method of the RLModule at hand. On configs that have a default exploration config, this must be done with `config.exploration_config={}`.
# (RolloutWorker pid=120909) 2024-05-11 14:32:02,494	WARNING algorithm_config.py:2578 -- Setting `exploration_config={}` because you set `_enable_rl_module_api=True`. When RLModule API are enabled, exploration_config can not be set. If you want to implement custom exploration behaviour, please modify the `forward_exploration` method of the RLModule at hand. On configs that have a default exploration config, this must be done with `config.exploration_config={}`.
# (RolloutWorker pid=120909) /usr/local/lib/python3.10/dist-packages/ray/rllib/connectors/agent/obs_preproc.py:40: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
# (RolloutWorker pid=120909)   self._preprocessor = get_preprocessor(obs_space)(
# (pid=120904) /usr/local/lib/python3.10/dist-packages/tensorflow_probability/python/__init__.py:57: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead. [repeated 2x across cluster]
# (pid=120904)   if (distutils.version.LooseVersion(tf.__version__) < [repeated 2x across cluster]
# (RolloutWorker pid=120904) 2024-05-11 14:32:03,708	WARNING deprecation.py:50 -- DeprecationWarning: `ValueNetworkMixin` has been deprecated. This will raise an error in the future!
# (RolloutWorker pid=120904) 2024-05-11 14:32:03,708	WARNING deprecation.py:50 -- DeprecationWarning: `LearningRateSchedule` has been deprecated. This will raise an error in the future!
# (RolloutWorker pid=120904) 2024-05-11 14:32:03,708	WARNING deprecation.py:50 -- DeprecationWarning: `EntropyCoeffSchedule` has been deprecated. This will raise an error in the future!
# (RolloutWorker pid=120904) 2024-05-11 14:32:03,708	WARNING deprecation.py:50 -- DeprecationWarning: `KLCoeffMixin` has been deprecated. This will raise an error in the future!
# /usr/local/lib/python3.10/dist-packages/ray/rllib/models/catalog.py:786: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   prep = cls(observation_space, options)
# 2024-05-11 14:32:03,802	WARNING algorithm_config.py:2578 -- Setting `exploration_config={}` because you set `_enable_rl_module_api=True`. When RLModule API are enabled, exploration_config can not be set. If you want to implement custom exploration behaviour, please modify the `forward_exploration` method of the RLModule at hand. On configs that have a default exploration config, this must be done with `config.exploration_config={}`.
# 2024-05-11 14:32:03,824	WARNING deprecation.py:50 -- DeprecationWarning: `ValueNetworkMixin` has been deprecated. This will raise an error in the future!
# 2024-05-11 14:32:03,826	WARNING deprecation.py:50 -- DeprecationWarning: `LearningRateSchedule` has been deprecated. This will raise an error in the future!
# 2024-05-11 14:32:03,829	WARNING deprecation.py:50 -- DeprecationWarning: `EntropyCoeffSchedule` has been deprecated. This will raise an error in the future!
# 2024-05-11 14:32:03,832	WARNING deprecation.py:50 -- DeprecationWarning: `KLCoeffMixin` has been deprecated. This will raise an error in the future!
# /usr/local/lib/python3.10/dist-packages/ray/rllib/policy/policy.py:1732: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   _, shape = ModelCatalog.get_action_shape(
# 2024-05-11 14:32:03,853	WARNING algorithm_config.py:2578 -- Setting `exploration_config={}` because you set `_enable_rl_module_api=True`. When RLModule API are enabled, exploration_config can not be set. If you want to implement custom exploration behaviour, please modify the `forward_exploration` method of the RLModule at hand. On configs that have a default exploration config, this must be done with `config.exploration_config={}`.
# 2024-05-11 14:32:03,876	WARNING algorithm_config.py:2578 -- Setting `exploration_config={}` because you set `_enable_rl_module_api=True`. When RLModule API are enabled, exploration_config can not be set. If you want to implement custom exploration behaviour, please modify the `forward_exploration` method of the RLModule at hand. On configs that have a default exploration config, this must be done with `config.exploration_config={}`.
# 2024-05-11 14:32:03,898	WARNING algorithm_config.py:2578 -- Setting `exploration_config={}` because you set `_enable_rl_module_api=True`. When RLModule API are enabled, exploration_config can not be set. If you want to implement custom exploration behaviour, please modify the `forward_exploration` method of the RLModule at hand. On configs that have a default exploration config, this must be done with `config.exploration_config={}`.
# 2024-05-11 14:32:03,916	WARNING algorithm_config.py:2578 -- Setting `exploration_config={}` because you set `_enable_rl_module_api=True`. When RLModule API are enabled, exploration_config can not be set. If you want to implement custom exploration behaviour, please modify the `forward_exploration` method of the RLModule at hand. On configs that have a default exploration config, this must be done with `config.exploration_config={}`.
# /usr/local/lib/python3.10/dist-packages/ray/rllib/connectors/agent/obs_preproc.py:40: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   self._preprocessor = get_preprocessor(obs_space)(
# 2024-05-11 14:32:05,143	INFO trainable.py:188 -- Trainable.setup took 23.938 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2024-05-11 14:32:05,148	WARNING util.py:68 -- Install gputil for GPU system monitoring.
# /usr/local/lib/python3.10/dist-packages/ray/rllib/connectors/agent/obs_preproc.py:40: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   self._preprocessor = get_preprocessor(obs_space)(

# %%
algo_asym.save("asym_pricing_model_checkpoint")
# Out:
# TrainingResult(checkpoint=Checkpoint(filesystem=local, path=asym_pricing_model_checkpoint), metrics={})

# %% [markdown]
# ##Symetric Policys##

# %%
agent_ids = OligopolyMarket()._agent_ids
sym_policies = {agent_id: f"policy_firm_0" for agent_id in agent_ids}  # Symmetric
asym_policies = {agent_id: f"policy_{agent_id}" for agent_id in agent_ids}  # Asymmetric
exploit_policies = sym_policies.copy()
#exploit_policies[list(exploit_policies.keys())[-1]] = "policy_firm_ex"

# %%
sym_policies
# Out:
# {'firm_0': 'policy_firm_0',
#  'firm_1': 'policy_firm_0',
#  'firm_2': 'policy_firm_0',
#  'firm_3': 'policy_firm_0',
#  'firm_4': 'policy_firm_0'}

# %%
if ray.is_initialized():
  ray.shutdown()
ray.init(num_cpus=4)
# Out:
# /usr/lib/python3.10/subprocess.py:1796: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = _posixsubprocess.fork_exec(
# 2024-05-11 14:33:29,398	INFO worker.py:1642 -- Started a local Ray instance.
# RayContext(dashboard_url='', python_version='3.10.12', ray_version='2.7.0', ray_commit='b4bba4717f5ba04ee25580fe8f88eed63ef0c5dc', protocol_version=None)

# %%
def policy_mapping_fn(agent_id, episode, worker, *, policies=None, **kwargs):
    return policies[agent_id]


policies = sym_policies
policy_mapping = partial(policy_mapping_fn, policies=policies)

config = (
        PPOConfig()
        .environment(OligopolyMarket)
        .framework('torch')
        .training(train_batch_size=1024, gamma=0.99)
        .resources(num_gpus=0)
        .rollouts(num_rollout_workers=3)
        .multi_agent(policies=list(policies.values()),
                     policy_mapping_fn=policy_mapping)
    )

stop = {"timesteps_total": 100000}

# THE WAY OF CODING IS A BIT DIFFERENT HERE FROM THE SINGLE AGENT ONE.
tuner = tune.Tuner(
        "PPO",
        param_space=config.to_dict(),
        run_config=air.RunConfig(stop=stop),
    )


tuner.fit()
# Out:
# 2024-05-11 14:33:35,422	WARNING algorithm_config.py:2578 -- Setting `exploration_config={}` because you set `_enable_rl_module_api=True`. When RLModule API are enabled, exploration_config can not be set. If you want to implement custom exploration behaviour, please modify the `forward_exploration` method of the RLModule at hand. On configs that have a default exploration config, this must be done with `config.exploration_config={}`.
# 2024-05-11 14:33:35,455	WARNING algorithm_config.py:2578 -- Setting `exploration_config={}` because you set `_enable_rl_module_api=True`. When RLModule API are enabled, exploration_config can not be set. If you want to implement custom exploration behaviour, please modify the `forward_exploration` method of the RLModule at hand. On configs that have a default exploration config, this must be done with `config.exploration_config={}`.
# 2024-05-11 14:33:35,473	WARNING algorithm_config.py:2578 -- Setting `exploration_config={}` because you set `_enable_rl_module_api=True`. When RLModule API are enabled, exploration_config can not be set. If you want to implement custom exploration behaviour, please modify the `forward_exploration` method of the RLModule at hand. On configs that have a default exploration config, this must be done with `config.exploration_config={}`.
# 2024-05-11 14:33:35,495	INFO tune.py:654 -- [output] This will use the new output engine with verbosity 1. To disable the new output and use the legacy output engine, set the environment variable RAY_AIR_NEW_OUTPUT=0. For more information, please see https://github.com/ray-project/ray/issues/36949
# 2024-05-11 14:33:35,552	WARNING algorithm_config.py:2578 -- Setting `exploration_config={}` because you set `_enable_rl_module_api=True`. When RLModule API are enabled, exploration_config can not be set. If you want to implement custom exploration behaviour, please modify the `forward_exploration` method of the RLModule at hand. On configs that have a default exploration config, this must be done with `config.exploration_config={}`.
# +------------------------------------------------------------+
# | Configuration for experiment     PPO_2024-05-11_14-33-35   |
# +------------------------------------------------------------+
# | Search algorithm                 BasicVariantGenerator     |
# | Scheduler                        FIFOScheduler             |
# | Number of trials                 1                         |
# +------------------------------------------------------------+
#
# View detailed results here: /root/ray_results/PPO_2024-05-11_14-33-35
# To visualize your results with TensorBoard, run: `tensorboard --logdir /root/ray_results/PPO_2024-05-11_14-33-35`
#
# Trial status: 1 PENDING
# Current time: 2024-05-11 14:33:35. Total running time: 0s
# Logical resource usage: 0/4 CPUs, 0/0 GPUs
# +--------------------------------------------+
# | Trial name                        status   |
# +--------------------------------------------+
# | PPO_OligopolyMarket_72fd0_00000   PENDING  |
# +--------------------------------------------+
# (pid=121598) /usr/local/lib/python3.10/dist-packages/tensorflow_probability/python/__init__.py:57: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
# (pid=121598)   if (distutils.version.LooseVersion(tf.__version__) <
# (pid=121598) DeprecationWarning: `DirectStepOptimizer` has been deprecated. This will raise an error in the future!
# (PPO pid=121598) 2024-05-11 14:33:46,488	WARNING algorithm_config.py:2578 -- Setting `exploration_config={}` because you set `_enable_rl_module_api=True`. When RLModule API are enabled, exploration_config can not be set. If you want to implement custom exploration behaviour, please modify the `forward_exploration` method of the RLModule at hand. On configs that have a default exploration config, this must be done with `config.exploration_config={}`.
# (PPO pid=121598) 2024-05-11 14:33:46,488	WARNING algorithm_config.py:672 -- Cannot create PPOConfig from given `config_dict`! Property __stdout_file__ not supported.
# Trial status: 1 PENDING
# Current time: 2024-05-11 14:34:05. Total running time: 30s
# Logical resource usage: 4.0/4 CPUs, 0/0 GPUs
# +--------------------------------------------+
# | Trial name                        status   |
# +--------------------------------------------+
# | PPO_OligopolyMarket_72fd0_00000   PENDING  |
# +--------------------------------------------+
# (pid=121673) /usr/local/lib/python3.10/dist-packages/tensorflow_probability/python/__init__.py:57: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
# (pid=121673)   if (distutils.version.LooseVersion(tf.__version__) <
# (pid=121673) DeprecationWarning: `DirectStepOptimizer` has been deprecated. This will raise an error in the future!
# (pid=121672) /usr/local/lib/python3.10/dist-packages/tensorflow_probability/python/__init__.py:57: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
# (pid=121672)   if (distutils.version.LooseVersion(tf.__version__) <
# (RolloutWorker pid=121673) /usr/local/lib/python3.10/dist-packages/ray/rllib/models/catalog.py:786: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
# (RolloutWorker pid=121673)   prep = cls(observation_space, options)
# (RolloutWorker pid=121673) 2024-05-11 14:34:09,706	WARNING algorithm_config.py:2578 -- Setting `exploration_config={}` because you set `_enable_rl_module_api=True`. When RLModule API are enabled, exploration_config can not be set. If you want to implement custom exploration behaviour, please modify the `forward_exploration` method of the RLModule at hand. On configs that have a default exploration config, this must be done with `config.exploration_config={}`.
# (RolloutWorker pid=121673) /usr/local/lib/python3.10/dist-packages/ray/rllib/policy/policy.py:1732: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
# (RolloutWorker pid=121673)   _, shape = ModelCatalog.get_action_shape(
# (RolloutWorker pid=121673) /usr/local/lib/python3.10/dist-packages/ray/rllib/connectors/agent/obs_preproc.py:40: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
# (RolloutWorker pid=121673)   self._preprocessor = get_preprocessor(obs_space)(
# (RolloutWorker pid=121672) 2024-05-11 14:34:11,957	WARNING deprecation.py:50 -- DeprecationWarning: `ValueNetworkMixin` has been deprecated. This will raise an error in the future!
# (RolloutWorker pid=121672) 2024-05-11 14:34:11,958	WARNING deprecation.py:50 -- DeprecationWarning: `LearningRateSchedule` has been deprecated. This will raise an error in the future!
# (RolloutWorker pid=121672) 2024-05-11 14:34:11,958	WARNING deprecation.py:50 -- DeprecationWarning: `EntropyCoeffSchedule` has been deprecated. This will raise an error in the future!
# (RolloutWorker pid=121672) 2024-05-11 14:34:11,958	WARNING deprecation.py:50 -- DeprecationWarning: `KLCoeffMixin` has been deprecated. This will raise an error in the future!
# (pid=121717) DeprecationWarning: `DirectStepOptimizer` has been deprecated. This will raise an error in the future! [repeated 2x across cluster]
# Trial PPO_OligopolyMarket_72fd0_00000 started with configuration:
# +---------------------------------------------------------------------------+
# | Trial PPO_OligopolyMarket_72fd0_00000 config                              |
# +---------------------------------------------------------------------------+
# | _AlgorithmConfig__prior_exploration_config/type        StochasticSampling |
# | _disable_action_flattening                                          False |
# | _disable_execution_plan_api                                          True |
# | _disable_initialize_loss_from_dummy_batch                           False |
# | _disable_preprocessor_api                                           False |
# | _enable_learner_api                                                  True |
# | _enable_rl_module_api                                                True |
# | _fake_gpus                                                          False |
# | _is_atari                                                                 |
# | _learner_class                                                            |
# | _tf_policy_handles_more_than_one_loss                               False |
# | action_mask_key                                               action_mask |
# | action_space                                                              |
# | actions_in_input_normalized                                         False |
# | always_attach_evaluation_results                                    False |
# | auto_wrap_old_gym_envs                                               True |
# | batch_mode                                              truncate_episodes |
# | callbacks                                            ...efaultCallbacks'> |
# | checkpoint_trainable_policies_only                                  False |
# | clip_actions                                                        False |
# | clip_param                                                            0.3 |
# | clip_rewards                                                              |
# | compress_observations                                               False |
# | count_steps_by                                                  env_steps |
# | create_env_on_driver                                                False |
# | custom_eval_function                                                      |
# | delay_between_worker_restarts_s                                       60. |
# | disable_env_checking                                                False |
# | eager_max_retraces                                                     20 |
# | eager_tracing                                                        True |
# | enable_async_evaluation                                             False |
# | enable_connectors                                                    True |
# | enable_tf1_exec_eagerly                                             False |
# | entropy_coeff                                                          0. |
# | entropy_coeff_schedule                                                    |
# | env                                                  ...OligopolyMarket'> |
# | env_runner_cls                                                            |
# | env_task_fn                                                               |
# | evaluation_config                                                         |
# | evaluation_duration                                                    10 |
# | evaluation_duration_unit                                         episodes |
# | evaluation_interval                                                       |
# | evaluation_num_workers                                                  0 |
# | evaluation_parallel_to_training                                     False |
# | evaluation_sample_timeout_s                                          180. |
# | explore                                                              True |
# | export_native_model_files                                           False |
# | fake_sampler                                                        False |
# | framework                                                           torch |
# | gamma                                                                0.99 |
# | grad_clip                                                                 |
# | grad_clip_by                                                  global_norm |
# | ignore_worker_failures                                              False |
# | in_evaluation                                                       False |
# | input                                                             sampler |
# | keep_per_episode_custom_metrics                                     False |
# | kl_coeff                                                              0.2 |
# | kl_target                                                            0.01 |
# | lambda                                                                 1. |
# | local_gpu_idx                                                           0 |
# | local_tf_session_args/inter_op_parallelism_threads                      8 |
# | local_tf_session_args/intra_op_parallelism_threads                      8 |
# | log_level                                                            WARN |
# | log_sys_usage                                                        True |
# | logger_config                                                             |
# | logger_creator                                                            |
# | lr                                                                0.00005 |
# | lr_schedule                                                               |
# | max_num_worker_restarts                                              1000 |
# | max_requests_in_flight_per_sampler_worker                               2 |
# | metrics_episode_collection_timeout_s                                  60. |
# | metrics_num_episodes_for_smoothing                                    100 |
# | min_sample_timesteps_per_iteration                                      0 |
# | min_time_s_per_iteration                                                  |
# | min_train_timesteps_per_iteration                                       0 |
# | model/_disable_action_flattening                                    False |
# | model/_disable_preprocessor_api                                     False |
# | model/_time_major                                                   False |
# | model/_use_default_native_models                                       -1 |
# | model/always_check_shapes                                           False |
# | model/attention_dim                                                    64 |
# | model/attention_head_dim                                               32 |
# | model/attention_init_gru_gate_bias                                    2.0 |
# | model/attention_memory_inference                                       50 |
# | model/attention_memory_training                                        50 |
# | model/attention_num_heads                                               1 |
# | model/attention_num_transformer_units                                   1 |
# | model/attention_position_wise_mlp_dim                                  32 |
# | model/attention_use_n_prev_actions                                      0 |
# | model/attention_use_n_prev_rewards                                      0 |
# | model/conv_activation                                                relu |
# | model/conv_filters                                                        |
# | model/custom_action_dist                                                  |
# | model/custom_model                                                        |
# | model/custom_preprocessor                                                 |
# | model/dim                                                              84 |
# | model/encoder_latent_dim                                                  |
# | model/fcnet_activation                                               tanh |
# | model/fcnet_hiddens                                            [256, 256] |
# | model/framestack                                                     True |
# | model/free_log_std                                                  False |
# | model/grayscale                                                     False |
# | model/lstm_cell_size                                                  256 |
# | model/lstm_use_prev_action                                          False |
# | model/lstm_use_prev_action_reward                                      -1 |
# | model/lstm_use_prev_reward                                          False |
# | model/max_seq_len                                                      20 |
# | model/no_final_linear                                               False |
# | model/post_fcnet_activation                                          relu |
# | model/post_fcnet_hiddens                                               [] |
# | model/use_attention                                                 False |
# | model/use_lstm                                                      False |
# | model/vf_share_layers                                               False |
# | model/zero_mean                                                      True |
# | normalize_actions                                                    True |
# | num_consecutive_worker_failures_tolerance                             100 |
# | num_cpus_for_driver                                                     1 |
# | num_cpus_per_learner_worker                                             1 |
# | num_cpus_per_worker                                                     1 |
# | num_envs_per_worker                                                     1 |
# | num_gpus                                                                0 |
# | num_gpus_per_learner_worker                                             0 |
# | num_gpus_per_worker                                                     0 |
# | num_learner_workers                                                     0 |
# | num_sgd_iter                                                           30 |
# | num_workers                                                             3 |
# | observation_filter                                               NoFilter |
# | observation_fn                                                            |
# | observation_space                                                         |
# | offline_sampling                                                    False |
# | ope_split_batch_by_episode                                           True |
# | output                                                                    |
# | output_compress_columns                                ['obs', 'new_obs'] |
# | output_max_file_size                                             67108864 |
# | placement_strategy                                                   PACK |
# | policies                                             ... 'policy_firm_0'] |
# | policies_to_train                                                         |
# | policy_map_cache                                                       -1 |
# | policy_map_capacity                                                   100 |
# | policy_mapping_fn                                    ...'policy_firm_0'}) |
# | policy_states_are_swappable                                         False |
# | postprocess_inputs                                                  False |
# | preprocessor_pref                                                deepmind |
# | recreate_failed_workers                                             False |
# | remote_env_batch_wait_ms                                                0 |
# | remote_worker_envs                                                  False |
# | render_env                                                          False |
# | replay_sequence_length                                                    |
# | restart_failed_sub_environments                                     False |
# | rl_module_spec                                                            |
# | rollout_fragment_length                                              auto |
# | sample_async                                                        False |
# | sample_collector                                     ...leListCollector'> |
# | sampler_perf_stats_ema_coef                                               |
# | seed                                                                      |
# | sgd_minibatch_size                                                    128 |
# | shuffle_buffer_size                                                     0 |
# | shuffle_sequences                                                    True |
# | simple_optimizer                                                       -1 |
# | sync_filters_on_rollout_workers_timeout_s                             60. |
# | synchronize_filters                                                    -1 |
# | tf_session_args/allow_soft_placement                                 True |
# | tf_session_args/device_count/CPU                                        1 |
# | tf_session_args/gpu_options/allow_growth                             True |
# | tf_session_args/inter_op_parallelism_threads                            2 |
# | tf_session_args/intra_op_parallelism_threads                            2 |
# | tf_session_args/log_device_placement                                False |
# | torch_compile_learner                                               False |
# | torch_compile_learner_dynamo_backend                             inductor |
# | torch_compile_learner_dynamo_mode                                         |
# | torch_compile_learner_what_to_compile                ...ile.FORWARD_TRAIN |
# | torch_compile_worker                                                False |
# | torch_compile_worker_dynamo_backend                                onnxrt |
# | torch_compile_worker_dynamo_mode                                          |
# | train_batch_size                                                     1024 |
# | update_worker_filter_stats                                           True |
# | use_critic                                                           True |
# | use_gae                                                              True |
# | use_kl_loss                                                          True |
# | use_worker_filter_stats                                              True |
# | validate_workers_after_construction                                  True |
# | vf_clip_param                                                         10. |
# | vf_loss_coeff                                                          1. |
# | vf_share_layers                                                        -1 |
# | worker_cls                                                             -1 |
# | worker_health_probe_timeout_s                                          60 |
# | worker_restore_timeout_s                                             1800 |
# +---------------------------------------------------------------------------+
# (PPO pid=121598) Trainable.setup took 27.443 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# (PPO pid=121598) Install gputil for GPU system monitoring.
# (pid=121717) /usr/local/lib/python3.10/dist-packages/tensorflow_probability/python/__init__.py:57: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
# (pid=121717)   if (distutils.version.LooseVersion(tf.__version__) <
# Trial status: 1 RUNNING
# Current time: 2024-05-11 14:34:35. Total running time: 1min 0s
# Logical resource usage: 4.0/4 CPUs, 0/0 GPUs
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                        status       iter     total time (s)     ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | PPO_OligopolyMarket_72fd0_00000   RUNNING         1            20.8916   1024      82296                 100013                61101.3                   80                     12 |
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# Trial status: 1 RUNNING
# Current time: 2024-05-11 14:35:05. Total running time: 1min 30s
# Logical resource usage: 4.0/4 CPUs, 0/0 GPUs
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                        status       iter     total time (s)     ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | PPO_OligopolyMarket_72fd0_00000   RUNNING         2            44.1595   2048    92245.7                 119103                61101.3                   80                     12 |
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# Trial status: 1 RUNNING
# Current time: 2024-05-11 14:35:35. Total running time: 2min 0s
# Logical resource usage: 4.0/4 CPUs, 0/0 GPUs
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                        status       iter     total time (s)     ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | PPO_OligopolyMarket_72fd0_00000   RUNNING         3            65.0631   3072     100863                 141230                61101.3                   80                     12 |
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# Trial status: 1 RUNNING
# Current time: 2024-05-11 14:36:06. Total running time: 2min 30s
# Logical resource usage: 4.0/4 CPUs, 0/0 GPUs
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                        status       iter     total time (s)     ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | PPO_OligopolyMarket_72fd0_00000   RUNNING         5            108.881   5120     112167                 142404                61101.3                   80                     12 |
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# Trial status: 1 RUNNING
# Current time: 2024-05-11 14:36:36. Total running time: 3min 0s
# Logical resource usage: 4.0/4 CPUs, 0/0 GPUs
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                        status       iter     total time (s)     ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | PPO_OligopolyMarket_72fd0_00000   RUNNING         6            132.885   6144     116397                 154180                61101.3                   80                     12 |
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# Trial status: 1 RUNNING
# Current time: 2024-05-11 14:37:06. Total running time: 3min 30s
# Logical resource usage: 4.0/4 CPUs, 0/0 GPUs
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                        status       iter     total time (s)     ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | PPO_OligopolyMarket_72fd0_00000   RUNNING         7            153.859   7168     120846                 164812                61101.3                   80                     12 |
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# Trial status: 1 RUNNING
# Current time: 2024-05-11 14:37:36. Total running time: 4min 0s
# Logical resource usage: 4.0/4 CPUs, 0/0 GPUs
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                        status       iter     total time (s)     ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | PPO_OligopolyMarket_72fd0_00000   RUNNING         9            197.611   9216     137728                 187013                87386.5                   80                     12 |
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# Trial status: 1 RUNNING
# Current time: 2024-05-11 14:38:06. Total running time: 4min 30s
# Logical resource usage: 4.0/4 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                        status       iter     total time (s)      ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | PPO_OligopolyMarket_72fd0_00000   RUNNING        10             218.52   10240     145693                 190715                98218.1                   80                     12 |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# Trial status: 1 RUNNING
# Current time: 2024-05-11 14:38:36. Total running time: 5min 0s
# Logical resource usage: 4.0/4 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                        status       iter     total time (s)      ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | PPO_OligopolyMarket_72fd0_00000   RUNNING        11             241.66   11264     154273                 194034                 101826                   80                     13 |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# Trial status: 1 RUNNING
# Current time: 2024-05-11 14:39:06. Total running time: 5min 30s
# Logical resource usage: 4.0/4 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                        status       iter     total time (s)      ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | PPO_OligopolyMarket_72fd0_00000   RUNNING        13            285.215   13312     168781                 196552                 120763                   80                     12 |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# Trial status: 1 RUNNING
# Current time: 2024-05-11 14:39:36. Total running time: 6min 0s
# Logical resource usage: 4.0/4 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                        status       iter     total time (s)      ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | PPO_OligopolyMarket_72fd0_00000   RUNNING        14             306.02   14336     176247                 213079                 140579                   80                     12 |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# Trial status: 1 RUNNING
# Current time: 2024-05-11 14:40:06. Total running time: 6min 30s
# Logical resource usage: 4.0/4 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                        status       iter     total time (s)      ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | PPO_OligopolyMarket_72fd0_00000   RUNNING        16            349.567   16384     190616                 220437                 159372                   80                     14 |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# Trial status: 1 RUNNING
# Current time: 2024-05-11 14:40:36. Total running time: 7min 0s
# Logical resource usage: 4.0/4 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                        status       iter     total time (s)      ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | PPO_OligopolyMarket_72fd0_00000   RUNNING        17            373.701   17408     195448                 229790                 163373                   80                     12 |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# Trial status: 1 RUNNING
# Current time: 2024-05-11 14:41:06. Total running time: 7min 30s
# Logical resource usage: 4.0/4 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                        status       iter     total time (s)      ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | PPO_OligopolyMarket_72fd0_00000   RUNNING        18            394.424   18432     200939                 234593                 168880                   80                     12 |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# Trial status: 1 RUNNING
# Current time: 2024-05-11 14:41:36. Total running time: 8min 1s
# Logical resource usage: 4.0/4 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                        status       iter     total time (s)      ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | PPO_OligopolyMarket_72fd0_00000   RUNNING        20            438.075   20480     210182                 234593                 176908                   80                     14 |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# Trial status: 1 RUNNING
# Current time: 2024-05-11 14:42:06. Total running time: 8min 31s
# Logical resource usage: 4.0/4 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                        status       iter     total time (s)      ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | PPO_OligopolyMarket_72fd0_00000   RUNNING        21            459.262   21504     213274                 234593                 181228                   80                     12 |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# Trial status: 1 RUNNING
# Current time: 2024-05-11 14:42:36. Total running time: 9min 1s
# Logical resource usage: 4.0/4 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                        status       iter     total time (s)      ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | PPO_OligopolyMarket_72fd0_00000   RUNNING        22            482.046   22528     214683                 234593                 197901                   80                     13 |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# Trial status: 1 RUNNING
# Current time: 2024-05-11 14:43:06. Total running time: 9min 31s
# Logical resource usage: 4.0/4 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                        status       iter     total time (s)      ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | PPO_OligopolyMarket_72fd0_00000   RUNNING        24            525.421   24576     217850                 235618                 197901                   80                     12 |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# Trial status: 1 RUNNING
# Current time: 2024-05-11 14:43:36. Total running time: 10min 1s
# Logical resource usage: 4.0/4 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                        status       iter     total time (s)      ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | PPO_OligopolyMarket_72fd0_00000   RUNNING        25            546.181   25600     219701                 235618                 197901                   80                     12 |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# Trial status: 1 RUNNING
# Current time: 2024-05-11 14:44:06. Total running time: 10min 31s
# Logical resource usage: 4.0/4 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                        status       iter     total time (s)      ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | PPO_OligopolyMarket_72fd0_00000   RUNNING        26            570.376   26624     220058                 235618                 197901                   80                     13 |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# Trial status: 1 RUNNING
# Current time: 2024-05-11 14:44:36. Total running time: 11min 1s
# Logical resource usage: 4.0/4 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                        status       iter     total time (s)      ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | PPO_OligopolyMarket_72fd0_00000   RUNNING        28            615.695   28672     222931                 238118                 197901                   80                     12 |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# Trial status: 1 RUNNING
# Current time: 2024-05-11 14:45:07. Total running time: 11min 31s
# Logical resource usage: 4.0/4 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                        status       iter     total time (s)      ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | PPO_OligopolyMarket_72fd0_00000   RUNNING        29            636.245   29696     225089                 240286                 197901                   80                     12 |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# Trial status: 1 RUNNING
# Current time: 2024-05-11 14:45:37. Total running time: 12min 1s
# Logical resource usage: 4.0/4 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                        status       iter     total time (s)      ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | PPO_OligopolyMarket_72fd0_00000   RUNNING        31            680.826   31744     230210                 245535                 216112                   80                     14 |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# Trial status: 1 RUNNING
# Current time: 2024-05-11 14:46:07. Total running time: 12min 31s
# Logical resource usage: 4.0/4 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                        status       iter     total time (s)      ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | PPO_OligopolyMarket_72fd0_00000   RUNNING        32             703.72   32768     231956                 246331                 216112                   80                     12 |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# Trial status: 1 RUNNING
# ...
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | PPO_OligopolyMarket_72fd0_00000   RUNNING        87            1949.41   89088     214638                 222080                 207630                   80                     12 |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# Trial status: 1 RUNNING
# Current time: 2024-05-11 15:07:39. Total running time: 34min 3s
# Logical resource usage: 4.0/4 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                        status       iter     total time (s)      ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | PPO_OligopolyMarket_72fd0_00000   RUNNING        89            1993.05   91136     213069                 219645                 207630                   80                     12 |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# Trial status: 1 RUNNING
# Current time: 2024-05-11 15:08:09. Total running time: 34min 33s
# Logical resource usage: 4.0/4 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                        status       iter     total time (s)      ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | PPO_OligopolyMarket_72fd0_00000   RUNNING        90            2016.35   92160     212456                 218535                 207611                   80                     12 |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# Trial status: 1 RUNNING
# Current time: 2024-05-11 15:08:39. Total running time: 35min 3s
# Logical resource usage: 4.0/4 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                        status       iter     total time (s)      ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | PPO_OligopolyMarket_72fd0_00000   RUNNING        91            2037.03   93184     211946                 215760                 207611                   80                     13 |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# Trial status: 1 RUNNING
# Current time: 2024-05-11 15:09:09. Total running time: 35min 34s
# Logical resource usage: 4.0/4 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                        status       iter     total time (s)      ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | PPO_OligopolyMarket_72fd0_00000   RUNNING        93            2083.55   95232     211564                 215644                 207611                   80                     12 |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# Trial status: 1 RUNNING
# Current time: 2024-05-11 15:09:39. Total running time: 36min 4s
# Logical resource usage: 4.0/4 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                        status       iter     total time (s)      ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | PPO_OligopolyMarket_72fd0_00000   RUNNING        94            2107.34   96256     211637                 215644                 207611                   80                     12 |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# Trial status: 1 RUNNING
# Current time: 2024-05-11 15:10:09. Total running time: 36min 34s
# Logical resource usage: 4.0/4 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                        status       iter     total time (s)      ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | PPO_OligopolyMarket_72fd0_00000   RUNNING        95            2128.51   97280     211345                 215644                 207011                   80                     13 |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# Trial status: 1 RUNNING
# Current time: 2024-05-11 15:10:39. Total running time: 37min 4s
# Logical resource usage: 4.0/4 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                        status       iter     total time (s)      ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | PPO_OligopolyMarket_72fd0_00000   RUNNING        97            2173.72   99328     210783                 215206                 207011                   80                     12 |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
#
# Trial PPO_OligopolyMarket_72fd0_00000 completed after 98 iterations at 2024-05-11 15:10:58. Total running time: 37min 23s
# +---------------------------------------------------------+
# | Trial PPO_OligopolyMarket_72fd0_00000 result            |
# +---------------------------------------------------------+
# | episodes_total                                     1252 |
# | num_env_steps_sampled                            100352 |
# | num_env_steps_trained                                 0 |
# | sampler_results/episode_len_mean                     80 |
# | sampler_results/episode_reward_mean              210841 |
# +---------------------------------------------------------+
#
# Trial status: 1 TERMINATED
# Current time: 2024-05-11 15:10:58. Total running time: 37min 23s
# Logical resource usage: 4.0/4 CPUs, 0/0 GPUs
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                        status         iter     total time (s)       ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | PPO_OligopolyMarket_72fd0_00000   TERMINATED       98            2197.86   100352     210841                 215480                 207011                   80                     12 |
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# (PPO pid=121598) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/root/ray_results/PPO_2024-05-11_14-33-35/PPO_OligopolyMarket_72fd0_00000_0_2024-05-11_14-33-35/checkpoint_000000)
# (RolloutWorker pid=121717) /usr/local/lib/python3.10/dist-packages/ray/rllib/connectors/agent/obs_preproc.py:40: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead. [repeated 9x across cluster]
# (PPO pid=121598)   prep = cls(observation_space, options) [repeated 3x across cluster]
# (PPO pid=121598) 2024-05-11 14:34:12,711	WARNING algorithm_config.py:2578 -- Setting `exploration_config={}` because you set `_enable_rl_module_api=True`. When RLModule API are enabled, exploration_config can not be set. If you want to implement custom exploration behaviour, please modify the `forward_exploration` method of the RLModule at hand. On configs that have a default exploration config, this must be done with `config.exploration_config={}`. [repeated 3x across cluster]
# (RolloutWorker pid=121717)   _, shape = ModelCatalog.get_action_shape( [repeated 3x across cluster]
# (RolloutWorker pid=121717)   self._preprocessor = get_preprocessor(obs_space)( [repeated 3x across cluster]
# (PPO pid=121598) 2024-05-11 14:34:12,723	WARNING deprecation.py:50 -- DeprecationWarning: `ValueNetworkMixin` has been deprecated. This will raise an error in the future!
# (PPO pid=121598) 2024-05-11 14:34:12,723	WARNING deprecation.py:50 -- DeprecationWarning: `LearningRateSchedule` has been deprecated. This will raise an error in the future!
# (PPO pid=121598) 2024-05-11 14:34:12,723	WARNING deprecation.py:50 -- DeprecationWarning: `EntropyCoeffSchedule` has been deprecated. This will raise an error in the future!
# (PPO pid=121598) 2024-05-11 14:34:12,724	WARNING deprecation.py:50 -- DeprecationWarning: `KLCoeffMixin` has been deprecated. This will raise an error in the future!
# ResultGrid<[
#   Result(
#     metrics={'custom_metrics': {}, 'episode_media': {}, 'info': {'learner': {'__all__': {'num_agent_steps_trained': 128.0, 'num_env_steps_trained': 5120.0, 'total_loss': 9.968995764255524}, 'policy_firm_0': {'total_loss': 9.968995764255524, 'policy_loss': 0.003862616914945344, 'vf_loss': 9.958984487851462, 'vf_loss_unclipped': 296778487.87333333, 'vf_explained_var': -2.2485852241516114e-06, 'entropy': -1.848565861483415, 'mean_kl_loss': 0.00910908493668103, 'default_optimizer_lr': 5.000000000000001e-05, 'curr_lr': 5e-05, 'curr_entropy_coeff': 0.0, 'curr_kl_coeff': 0.675000011920929}}, 'num_env_steps_sampled': 100352, 'num_env_steps_trained': 0, 'num_agent_steps_sampled': 501760, 'num_agent_steps_trained': 0}, 'sampler_results': {'episode_reward_max': 215479.6006716448, 'episode_reward_min': 207010.75716089614, 'episode_reward_mean': 210840.76620346867, 'episode_len_mean': 80.0, 'episode_media': {}, 'episodes_this_iter': 12, 'policy_reward_min': {'policy_firm_0': 34486.570126065206}, 'policy_reward_max': {'policy_firm_0': 50740.23051092264}, 'policy_reward_mean': {'policy_firm_0': 42168.15324069373}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [211193.77647493864, 211640.3199546949, 211199.64406376414, 208878.61226936165, 213923.3543532725, 209326.49982029066, 212278.96859892027, 214885.29617629654, 208260.67370176667, 208001.2094417241, 210156.04306396667, 209891.58507509454, 211420.29555138492, 210023.33122322802, 209866.72090961767, 211210.448536577, 211359.88266738568, 207716.9596586926, 211220.5434296898, 211669.9740954861, 208084.20639997974, 210441.71225459056, 210248.34327778174, 210813.46123505066, 211291.75867539845, 213755.64793759785, 210941.35211288094, 211560.3006783597, 210919.86984456825, 210283.5516942078, 213596.67586979538, 209490.55574369855, 211462.7037153102, 213168.89925492043, 213362.59998392686, 210183.97519929035, 212359.67821059094, 212672.52962855145, 211444.9755242063, 212062.28515228885, 211131.8064681984, 213988.28372936178, 213897.47568217138, 214278.55874691572, 214107.24252679796, 211003.07274789264, 212270.19308817477, 208382.20427183624, 211937.9665279846, 210668.17774062965, 207010.75716089614, 209865.8480361419, 209071.08978867024, 210383.06182393734, 209375.04396465747, 210105.47062208512, 211847.25424320536, 209858.33671566698, 209928.94190870877, 212150.43102864866, 209823.29806042698, 210356.31520816204, 208912.83037258332, 209470.18984692014, 209566.57119849703, 208353.16549748572, 208305.32929360488, 208726.65491570986, 210334.99991399236, 211505.57381199673, 209173.18008774664, 211382.23625047982, 207879.6416027748, 209814.0829513762, 208115.63003313722, 209215.16121190414, 208067.7120488071, 210147.0817915715, 209778.69222350494, 209703.90567650425, 211138.77062004703, 209992.4919623716, 210628.86850520255, 210450.243572175, 209325.44327201406, 211444.52871940436, 208971.4971738933, 213989.50900487625, 212265.2344923143, 215077.53928302086, 209863.80513362738, 209510.03863935356, 209785.93549831974, 215479.6006716448, 213676.76227577304, 213129.41576276132, 209391.3859923602, 210621.72465316398, 214360.89852890966, 212810.23630671634], 'episode_lengths': [80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80], 'policy_policy_firm_0_reward': [45275.69168621683, 43857.07284743598, 41706.14796327774, 38804.16366887532, 41550.7003091328, 43713.1431888241, 39293.68500612079, 39281.481347290566, 44796.910117683496, 44555.10029477601, 43054.31257686282, 46868.464434243346, 40550.64779044881, 44339.65622868819, 36386.563033521, 42610.77018946195, 41634.104252389414, 45707.20308498599, 39545.866712129166, 39380.66803039509, 42519.498956355725 ...
#     path='/root/ray_results/PPO_2024-05-11_14-33-35/PPO_OligopolyMarket_72fd0_00000_0_2024-05-11_14-33-35',
#     filesystem='local',
#     checkpoint=Checkpoint(filesystem=local, path=/root/ray_results/PPO_2024-05-11_14-33-35/PPO_OligopolyMarket_72fd0_00000_0_2024-05-11_14-33-35/checkpoint_000000)
#   )
# ]>

# %% [markdown]
# **path=/root/ray_results/PPO_2024-05-11_14-33-35/PPO_OligopolyMarket_72fd0_00000_0_2024-05-11_14-33-35/checkpoint_000000**

# %%
algo_sym = Algorithm.from_checkpoint("/root/ray_results/PPO_2024-05-11_14-33-35/PPO_OligopolyMarket_72fd0_00000_0_2024-05-11_14-33-35/checkpoint_000000")
# Out:
# 2024-05-11 15:12:18,010	WARNING algorithm_config.py:2578 -- Setting `exploration_config={}` because you set `_enable_rl_module_api=True`. When RLModule API are enabled, exploration_config can not be set. If you want to implement custom exploration behaviour, please modify the `forward_exploration` method of the RLModule at hand. On configs that have a default exploration config, this must be done with `config.exploration_config={}`.
# 2024-05-11 15:12:18,018	WARNING algorithm_config.py:2578 -- Setting `exploration_config={}` because you set `_enable_rl_module_api=True`. When RLModule API are enabled, exploration_config can not be set. If you want to implement custom exploration behaviour, please modify the `forward_exploration` method of the RLModule at hand. On configs that have a default exploration config, this must be done with `config.exploration_config={}`.
# /usr/local/lib/python3.10/dist-packages/ray/rllib/algorithms/algorithm.py:484: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# `UnifiedLogger` will be removed in Ray 2.7.
#   return UnifiedLogger(config, logdir, loggers=None)
# /usr/local/lib/python3.10/dist-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `JsonLogger interface is deprecated in favor of the `ray.tune.json.JsonLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /usr/local/lib/python3.10/dist-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `CSVLogger interface is deprecated in favor of the `ray.tune.csv.CSVLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /usr/local/lib/python3.10/dist-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `TBXLogger interface is deprecated in favor of the `ray.tune.tensorboardx.TBXLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# (pid=130963) /usr/local/lib/python3.10/dist-packages/tensorflow_probability/python/__init__.py:57: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
# (pid=130963)   if (distutils.version.LooseVersion(tf.__version__) <
# (pid=130963) DeprecationWarning: `DirectStepOptimizer` has been deprecated. This will raise an error in the future!
# (RolloutWorker pid=130963) /usr/local/lib/python3.10/dist-packages/ray/rllib/models/catalog.py:786: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
# (RolloutWorker pid=130963)   prep = cls(observation_space, options)
# (RolloutWorker pid=130963) 2024-05-11 15:12:46,178	WARNING algorithm_config.py:2578 -- Setting `exploration_config={}` because you set `_enable_rl_module_api=True`. When RLModule API are enabled, exploration_config can not be set. If you want to implement custom exploration behaviour, please modify the `forward_exploration` method of the RLModule at hand. On configs that have a default exploration config, this must be done with `config.exploration_config={}`.
# (pid=130987) /usr/local/lib/python3.10/dist-packages/tensorflow_probability/python/__init__.py:57: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead. [repeated 2x across cluster]
# (pid=130987)   if (distutils.version.LooseVersion(tf.__version__) < [repeated 2x across cluster]
# (RolloutWorker pid=130963) 2024-05-11 15:12:46,221	WARNING deprecation.py:50 -- DeprecationWarning: `ValueNetworkMixin` has been deprecated. This will raise an error in the future!
# (RolloutWorker pid=130963) 2024-05-11 15:12:46,221	WARNING deprecation.py:50 -- DeprecationWarning: `LearningRateSchedule` has been deprecated. This will raise an error in the future!
# (RolloutWorker pid=130963) 2024-05-11 15:12:46,221	WARNING deprecation.py:50 -- DeprecationWarning: `EntropyCoeffSchedule` has been deprecated. This will raise an error in the future!
# (RolloutWorker pid=130963) 2024-05-11 15:12:46,221	WARNING deprecation.py:50 -- DeprecationWarning: `KLCoeffMixin` has been deprecated. This will raise an error in the future!
# (RolloutWorker pid=130963) /usr/local/lib/python3.10/dist-packages/ray/rllib/policy/policy.py:1732: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
# (RolloutWorker pid=130963)   _, shape = ModelCatalog.get_action_shape(
# (RolloutWorker pid=130963) /usr/local/lib/python3.10/dist-packages/ray/rllib/connectors/agent/obs_preproc.py:40: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
# (RolloutWorker pid=130963)   self._preprocessor = get_preprocessor(obs_space)(
# /usr/local/lib/python3.10/dist-packages/ray/rllib/models/catalog.py:786: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   prep = cls(observation_space, options)
# 2024-05-11 15:12:46,625	WARNING algorithm_config.py:2578 -- Setting `exploration_config={}` because you set `_enable_rl_module_api=True`. When RLModule API are enabled, exploration_config can not be set. If you want to implement custom exploration behaviour, please modify the `forward_exploration` method of the RLModule at hand. On configs that have a default exploration config, this must be done with `config.exploration_config={}`.
# /usr/local/lib/python3.10/dist-packages/ray/rllib/policy/policy.py:1732: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   _, shape = ModelCatalog.get_action_shape(
# 2024-05-11 15:12:46,685	INFO trainable.py:188 -- Trainable.setup took 28.559 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2024-05-11 15:12:46,688	WARNING util.py:68 -- Install gputil for GPU system monitoring.
# (RolloutWorker pid=130963) /usr/local/lib/python3.10/dist-packages/ray/rllib/connectors/agent/obs_preproc.py:40: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
# (RolloutWorker pid=130963)   self._preprocessor = get_preprocessor(obs_space)(

# %%
algo_sym.save("sym_pricing_model_checkpoint")
# Out:
# TrainingResult(checkpoint=Checkpoint(filesystem=local, path=sym_pricing_model_checkpoint), metrics={})

# %% [markdown]
# ##Policy For Firm_x

# %%
agent_ids = OligopolyMarket()._agent_ids
firm_x_policies = {agent_id: f"policy_firm_0" for agent_id in agent_ids}  # Symmetric
asym_policies = {agent_id: f"policy_{agent_id}" for agent_id in agent_ids}  # Asymmetric
exploit_policies = firm_x_policies.copy()
exploit_policies[list(exploit_policies.keys())[-1]] = "policy_firm_ex"

# %%
exploit_policies
# Out:
# {'firm_0': 'policy_firm_0',
#  'firm_1': 'policy_firm_0',
#  'firm_2': 'policy_firm_0',
#  'firm_3': 'policy_firm_0',
#  'firm_4': 'policy_firm_ex'}

# %%
if ray.is_initialized():
  ray.shutdown()
ray.init(num_cpus=4)
# Out:
# /usr/lib/python3.10/subprocess.py:1796: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = _posixsubprocess.fork_exec(
# 2024-05-11 15:35:08,936	INFO worker.py:1642 -- Started a local Ray instance.
# RayContext(dashboard_url='', python_version='3.10.12', ray_version='2.7.0', ray_commit='b4bba4717f5ba04ee25580fe8f88eed63ef0c5dc', protocol_version=None)

# %%
def policy_mapping_fn(agent_id, episode, worker, *, policies=None, **kwargs):
    return policies[agent_id]


policies = exploit_policies
policy_mapping = partial(policy_mapping_fn, policies=policies)

config = (
        PPOConfig()
        .environment(OligopolyMarket)
        .framework('torch')
        .training(train_batch_size=1024, gamma=0.99)
        .resources(num_gpus=0)
        .rollouts(num_rollout_workers=3)
        .multi_agent(policies=list(policies.values()),
                     policy_mapping_fn=policy_mapping)
    )

stop = {"timesteps_total": 100000}

# THE WAY OF CODING IS A BIT DIFFERENT HERE FROM THE SINGLE AGENT ONE.
tuner = tune.Tuner(
        "PPO",
        param_space=config.to_dict(),
        run_config=air.RunConfig(stop=stop),
    )


tuner.fit()
# Out:
# 2024-05-11 15:35:18,364	WARNING algorithm_config.py:2578 -- Setting `exploration_config={}` because you set `_enable_rl_module_api=True`. When RLModule API are enabled, exploration_config can not be set. If you want to implement custom exploration behaviour, please modify the `forward_exploration` method of the RLModule at hand. On configs that have a default exploration config, this must be done with `config.exploration_config={}`.
# 2024-05-11 15:35:18,386	WARNING algorithm_config.py:2578 -- Setting `exploration_config={}` because you set `_enable_rl_module_api=True`. When RLModule API are enabled, exploration_config can not be set. If you want to implement custom exploration behaviour, please modify the `forward_exploration` method of the RLModule at hand. On configs that have a default exploration config, this must be done with `config.exploration_config={}`.
# 2024-05-11 15:35:18,401	WARNING algorithm_config.py:2578 -- Setting `exploration_config={}` because you set `_enable_rl_module_api=True`. When RLModule API are enabled, exploration_config can not be set. If you want to implement custom exploration behaviour, please modify the `forward_exploration` method of the RLModule at hand. On configs that have a default exploration config, this must be done with `config.exploration_config={}`.
# 2024-05-11 15:35:18,417	INFO tune.py:654 -- [output] This will use the new output engine with verbosity 1. To disable the new output and use the legacy output engine, set the environment variable RAY_AIR_NEW_OUTPUT=0. For more information, please see https://github.com/ray-project/ray/issues/36949
# 2024-05-11 15:35:18,442	WARNING algorithm_config.py:2578 -- Setting `exploration_config={}` because you set `_enable_rl_module_api=True`. When RLModule API are enabled, exploration_config can not be set. If you want to implement custom exploration behaviour, please modify the `forward_exploration` method of the RLModule at hand. On configs that have a default exploration config, this must be done with `config.exploration_config={}`.
# +------------------------------------------------------------+
# | Configuration for experiment     PPO_2024-05-11_15-35-18   |
# +------------------------------------------------------------+
# | Search algorithm                 BasicVariantGenerator     |
# | Scheduler                        FIFOScheduler             |
# | Number of trials                 1                         |
# +------------------------------------------------------------+
#
# View detailed results here: /root/ray_results/PPO_2024-05-11_15-35-18
# To visualize your results with TensorBoard, run: `tensorboard --logdir /root/ray_results/PPO_2024-05-11_15-35-18`
#
# Trial status: 1 PENDING
# Current time: 2024-05-11 15:35:18. Total running time: 0s
# Logical resource usage: 0/4 CPUs, 0/0 GPUs
# +--------------------------------------------+
# | Trial name                        status   |
# +--------------------------------------------+
# | PPO_OligopolyMarket_121a4_00000   PENDING  |
# +--------------------------------------------+
# (pid=136723) /usr/local/lib/python3.10/dist-packages/tensorflow_probability/python/__init__.py:57: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
# (pid=136723)   if (distutils.version.LooseVersion(tf.__version__) <
# (pid=136723) DeprecationWarning: `DirectStepOptimizer` has been deprecated. This will raise an error in the future!
# (PPO pid=136723) 2024-05-11 15:35:29,436	WARNING algorithm_config.py:2578 -- Setting `exploration_config={}` because you set `_enable_rl_module_api=True`. When RLModule API are enabled, exploration_config can not be set. If you want to implement custom exploration behaviour, please modify the `forward_exploration` method of the RLModule at hand. On configs that have a default exploration config, this must be done with `config.exploration_config={}`.
# (PPO pid=136723) 2024-05-11 15:35:29,437	WARNING algorithm_config.py:672 -- Cannot create PPOConfig from given `config_dict`! Property __stdout_file__ not supported.
# Trial status: 1 PENDING
# Current time: 2024-05-11 15:35:48. Total running time: 30s
# Logical resource usage: 4.0/4 CPUs, 0/0 GPUs
# +--------------------------------------------+
# | Trial name                        status   |
# +--------------------------------------------+
# | PPO_OligopolyMarket_121a4_00000   PENDING  |
# +--------------------------------------------+
# (pid=136796) /usr/local/lib/python3.10/dist-packages/tensorflow_probability/python/__init__.py:57: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
# (pid=136796)   if (distutils.version.LooseVersion(tf.__version__) <
# (pid=136796) DeprecationWarning: `DirectStepOptimizer` has been deprecated. This will raise an error in the future!
# (pid=136795) /usr/local/lib/python3.10/dist-packages/tensorflow_probability/python/__init__.py:57: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
# (pid=136795)   if (distutils.version.LooseVersion(tf.__version__) <
# (RolloutWorker pid=136796) /usr/local/lib/python3.10/dist-packages/ray/rllib/models/catalog.py:786: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
# (RolloutWorker pid=136796)   prep = cls(observation_space, options)
# (RolloutWorker pid=136796) 2024-05-11 15:35:52,082	WARNING algorithm_config.py:2578 -- Setting `exploration_config={}` because you set `_enable_rl_module_api=True`. When RLModule API are enabled, exploration_config can not be set. If you want to implement custom exploration behaviour, please modify the `forward_exploration` method of the RLModule at hand. On configs that have a default exploration config, this must be done with `config.exploration_config={}`.
# (RolloutWorker pid=136796) /usr/local/lib/python3.10/dist-packages/ray/rllib/policy/policy.py:1732: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
# (RolloutWorker pid=136796)   _, shape = ModelCatalog.get_action_shape(
# (RolloutWorker pid=136796) 2024-05-11 15:35:52,128	WARNING algorithm_config.py:2578 -- Setting `exploration_config={}` because you set `_enable_rl_module_api=True`. When RLModule API are enabled, exploration_config can not be set. If you want to implement custom exploration behaviour, please modify the `forward_exploration` method of the RLModule at hand. On configs that have a default exploration config, this must be done with `config.exploration_config={}`.
# (RolloutWorker pid=136796) /usr/local/lib/python3.10/dist-packages/ray/rllib/connectors/agent/obs_preproc.py:40: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
# (RolloutWorker pid=136796)   self._preprocessor = get_preprocessor(obs_space)(
# (RolloutWorker pid=136795) 2024-05-11 15:35:53,191	WARNING deprecation.py:50 -- DeprecationWarning: `ValueNetworkMixin` has been deprecated. This will raise an error in the future!
# (RolloutWorker pid=136795) 2024-05-11 15:35:53,191	WARNING deprecation.py:50 -- DeprecationWarning: `LearningRateSchedule` has been deprecated. This will raise an error in the future!
# (RolloutWorker pid=136795) 2024-05-11 15:35:53,191	WARNING deprecation.py:50 -- DeprecationWarning: `EntropyCoeffSchedule` has been deprecated. This will raise an error in the future!
# (RolloutWorker pid=136795) 2024-05-11 15:35:53,191	WARNING deprecation.py:50 -- DeprecationWarning: `KLCoeffMixin` has been deprecated. This will raise an error in the future!
# Trial PPO_OligopolyMarket_121a4_00000 started with configuration:
# +---------------------------------------------------------------------------+
# | Trial PPO_OligopolyMarket_121a4_00000 config                              |
# +---------------------------------------------------------------------------+
# | _AlgorithmConfig__prior_exploration_config/type        StochasticSampling |
# | _disable_action_flattening                                          False |
# | _disable_execution_plan_api                                          True |
# | _disable_initialize_loss_from_dummy_batch                           False |
# | _disable_preprocessor_api                                           False |
# | _enable_learner_api                                                  True |
# | _enable_rl_module_api                                                True |
# | _fake_gpus                                                          False |
# | _is_atari                                                                 |
# | _learner_class                                                            |
# | _tf_policy_handles_more_than_one_loss                               False |
# | action_mask_key                                               action_mask |
# | action_space                                                              |
# | actions_in_input_normalized                                         False |
# | always_attach_evaluation_results                                    False |
# | auto_wrap_old_gym_envs                                               True |
# | batch_mode                                              truncate_episodes |
# | callbacks                                            ...efaultCallbacks'> |
# | checkpoint_trainable_policies_only                                  False |
# | clip_actions                                                        False |
# | clip_param                                                            0.3 |
# | clip_rewards                                                              |
# | compress_observations                                               False |
# | count_steps_by                                                  env_steps |
# | create_env_on_driver                                                False |
# | custom_eval_function                                                      |
# | delay_between_worker_restarts_s                                       60. |
# | disable_env_checking                                                False |
# | eager_max_retraces                                                     20 |
# | eager_tracing                                                        True |
# | enable_async_evaluation                                             False |
# | enable_connectors                                                    True |
# | enable_tf1_exec_eagerly                                             False |
# | entropy_coeff                                                          0. |
# | entropy_coeff_schedule                                                    |
# | env                                                  ...OligopolyMarket'> |
# | env_runner_cls                                                            |
# | env_task_fn                                                               |
# | evaluation_config                                                         |
# | evaluation_duration                                                    10 |
# | evaluation_duration_unit                                         episodes |
# | evaluation_interval                                                       |
# | evaluation_num_workers                                                  0 |
# | evaluation_parallel_to_training                                     False |
# | evaluation_sample_timeout_s                                          180. |
# | explore                                                              True |
# | export_native_model_files                                           False |
# | fake_sampler                                                        False |
# | framework                                                           torch |
# | gamma                                                                0.99 |
# | grad_clip                                                                 |
# | grad_clip_by                                                  global_norm |
# | ignore_worker_failures                                              False |
# | in_evaluation                                                       False |
# | input                                                             sampler |
# | keep_per_episode_custom_metrics                                     False |
# | kl_coeff                                                              0.2 |
# | kl_target                                                            0.01 |
# | lambda                                                                 1. |
# | local_gpu_idx                                                           0 |
# | local_tf_session_args/inter_op_parallelism_threads                      8 |
# | local_tf_session_args/intra_op_parallelism_threads                      8 |
# | log_level                                                            WARN |
# | log_sys_usage                                                        True |
# | logger_config                                                             |
# | logger_creator                                                            |
# | lr                                                                0.00005 |
# | lr_schedule                                                               |
# | max_num_worker_restarts                                              1000 |
# | max_requests_in_flight_per_sampler_worker                               2 |
# | metrics_episode_collection_timeout_s                                  60. |
# | metrics_num_episodes_for_smoothing                                    100 |
# | min_sample_timesteps_per_iteration                                      0 |
# | min_time_s_per_iteration                                                  |
# | min_train_timesteps_per_iteration                                       0 |
# | model/_disable_action_flattening                                    False |
# | model/_disable_preprocessor_api                                     False |
# | model/_time_major                                                   False |
# | model/_use_default_native_models                                       -1 |
# | model/always_check_shapes                                           False |
# | model/attention_dim                                                    64 |
# | model/attention_head_dim                                               32 |
# | model/attention_init_gru_gate_bias                                    2.0 |
# | model/attention_memory_inference                                       50 |
# | model/attention_memory_training                                        50 |
# | model/attention_num_heads                                               1 |
# | model/attention_num_transformer_units                                   1 |
# | model/attention_position_wise_mlp_dim                                  32 |
# | model/attention_use_n_prev_actions                                      0 |
# | model/attention_use_n_prev_rewards                                      0 |
# | model/conv_activation                                                relu |
# | model/conv_filters                                                        |
# | model/custom_action_dist                                                  |
# | model/custom_model                                                        |
# | model/custom_preprocessor                                                 |
# | model/dim                                                              84 |
# | model/encoder_latent_dim                                                  |
# | model/fcnet_activation                                               tanh |
# | model/fcnet_hiddens                                            [256, 256] |
# | model/framestack                                                     True |
# | model/free_log_std                                                  False |
# | model/grayscale                                                     False |
# | model/lstm_cell_size                                                  256 |
# | model/lstm_use_prev_action                                          False |
# | model/lstm_use_prev_action_reward                                      -1 |
# | model/lstm_use_prev_reward                                          False |
# | model/max_seq_len                                                      20 |
# | model/no_final_linear                                               False |
# | model/post_fcnet_activation                                          relu |
# | model/post_fcnet_hiddens                                               [] |
# | model/use_attention                                                 False |
# | model/use_lstm                                                      False |
# | model/vf_share_layers                                               False |
# | model/zero_mean                                                      True |
# | normalize_actions                                                    True |
# | num_consecutive_worker_failures_tolerance                             100 |
# | num_cpus_for_driver                                                     1 |
# | num_cpus_per_learner_worker                                             1 |
# | num_cpus_per_worker                                                     1 |
# | num_envs_per_worker                                                     1 |
# | num_gpus                                                                0 |
# | num_gpus_per_learner_worker                                             0 |
# | num_gpus_per_worker                                                     0 |
# | num_learner_workers                                                     0 |
# | num_sgd_iter                                                           30 |
# | num_workers                                                             3 |
# | observation_filter                                               NoFilter |
# | observation_fn                                                            |
# | observation_space                                                         |
# | offline_sampling                                                    False |
# | ope_split_batch_by_episode                                           True |
# | output                                                                    |
# | output_compress_columns                                ['obs', 'new_obs'] |
# | output_max_file_size                                             67108864 |
# | placement_strategy                                                   PACK |
# | policies                                             ...'policy_firm_ex'] |
# | policies_to_train                                                         |
# | policy_map_cache                                                       -1 |
# | policy_map_capacity                                                   100 |
# | policy_mapping_fn                                    ...policy_firm_ex'}) |
# | policy_states_are_swappable                                         False |
# | postprocess_inputs                                                  False |
# | preprocessor_pref                                                deepmind |
# | recreate_failed_workers                                             False |
# | remote_env_batch_wait_ms                                                0 |
# | remote_worker_envs                                                  False |
# | render_env                                                          False |
# | replay_sequence_length                                                    |
# | restart_failed_sub_environments                                     False |
# | rl_module_spec                                                            |
# | rollout_fragment_length                                              auto |
# | sample_async                                                        False |
# | sample_collector                                     ...leListCollector'> |
# | sampler_perf_stats_ema_coef                                               |
# | seed                                                                      |
# | sgd_minibatch_size                                                    128 |
# | shuffle_buffer_size                                                     0 |
# | shuffle_sequences                                                    True |
# | simple_optimizer                                                       -1 |
# | sync_filters_on_rollout_workers_timeout_s                             60. |
# | synchronize_filters                                                    -1 |
# | tf_session_args/allow_soft_placement                                 True |
# | tf_session_args/device_count/CPU                                        1 |
# | tf_session_args/gpu_options/allow_growth                             True |
# | tf_session_args/inter_op_parallelism_threads                            2 |
# | tf_session_args/intra_op_parallelism_threads                            2 |
# | tf_session_args/log_device_placement                                False |
# | torch_compile_learner                                               False |
# | torch_compile_learner_dynamo_backend                             inductor |
# | torch_compile_learner_dynamo_mode                                         |
# | torch_compile_learner_what_to_compile                ...ile.FORWARD_TRAIN |
# | torch_compile_worker                                                False |
# | torch_compile_worker_dynamo_backend                                onnxrt |
# | torch_compile_worker_dynamo_mode                                          |
# | train_batch_size                                                     1024 |
# | update_worker_filter_stats                                           True |
# | use_critic                                                           True |
# | use_gae                                                              True |
# | use_kl_loss                                                          True |
# | use_worker_filter_stats                                              True |
# | validate_workers_after_construction                                  True |
# | vf_clip_param                                                         10. |
# | vf_loss_coeff                                                          1. |
# | vf_share_layers                                                        -1 |
# | worker_cls                                                             -1 |
# | worker_health_probe_timeout_s                                          60 |
# | worker_restore_timeout_s                                             1800 |
# +---------------------------------------------------------------------------+
# (PPO pid=136723) Trainable.setup took 25.809 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# (PPO pid=136723) Install gputil for GPU system monitoring.
# (pid=136827) DeprecationWarning: `DirectStepOptimizer` has been deprecated. This will raise an error in the future! [repeated 2x across cluster]
# Trial status: 1 RUNNING
# Current time: 2024-05-11 15:36:18. Total running time: 1min 0s
# Logical resource usage: 4.0/4 CPUs, 0/0 GPUs
# +--------------------------------------------+
# | Trial name                        status   |
# +--------------------------------------------+
# | PPO_OligopolyMarket_121a4_00000   RUNNING  |
# +--------------------------------------------+
# Trial status: 1 RUNNING
# Current time: 2024-05-11 15:36:48. Total running time: 1min 30s
# Logical resource usage: 4.0/4 CPUs, 0/0 GPUs
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                        status       iter     total time (s)     ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | PPO_OligopolyMarket_121a4_00000   RUNNING         1            33.8447   1024    -9575.7                15547.6               -23786.6                   80                     12 |
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# Trial status: 1 RUNNING
# Current time: 2024-05-11 15:37:18. Total running time: 2min 0s
# Logical resource usage: 4.0/4 CPUs, 0/0 GPUs
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                        status       iter     total time (s)     ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | PPO_OligopolyMarket_121a4_00000   RUNNING         2            68.5262   2048    964.252                24537.3               -23786.6                   80                     12 |
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# Trial status: 1 RUNNING
# Current time: 2024-05-11 15:37:48. Total running time: 2min 30s
# Logical resource usage: 4.0/4 CPUs, 0/0 GPUs
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                        status       iter     total time (s)     ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | PPO_OligopolyMarket_121a4_00000   RUNNING         3            99.8155   3072    13826.1                61446.6               -23786.6                   80                     12 |
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# Trial status: 1 RUNNING
# Current time: 2024-05-11 15:38:18. Total running time: 3min 0s
# Logical resource usage: 4.0/4 CPUs, 0/0 GPUs
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                        status       iter     total time (s)     ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | PPO_OligopolyMarket_121a4_00000   RUNNING         4            131.113   4096    18825.5                62476.2               -23786.6                   80                     15 |
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# Trial status: 1 RUNNING
# Current time: 2024-05-11 15:38:48. Total running time: 3min 30s
# Logical resource usage: 4.0/4 CPUs, 0/0 GPUs
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                        status       iter     total time (s)     ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | PPO_OligopolyMarket_121a4_00000   RUNNING         5            162.739   5120    25106.4                69210.2               -23786.6                   80                     12 |
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# Trial status: 1 RUNNING
# Current time: 2024-05-11 15:39:18. Total running time: 4min 0s
# Logical resource usage: 4.0/4 CPUs, 0/0 GPUs
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                        status       iter     total time (s)     ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | PPO_OligopolyMarket_121a4_00000   RUNNING         6            194.754   6144    30827.6                  74307               -23786.6                   80                     12 |
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# Trial status: 1 RUNNING
# Current time: 2024-05-11 15:39:48. Total running time: 4min 30s
# Logical resource usage: 4.0/4 CPUs, 0/0 GPUs
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                        status       iter     total time (s)     ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | PPO_OligopolyMarket_121a4_00000   RUNNING         7            226.224   7168    35799.6                89245.7               -23786.6                   80                     12 |
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# Trial status: 1 RUNNING
# Current time: 2024-05-11 15:40:19. Total running time: 5min 0s
# Logical resource usage: 4.0/4 CPUs, 0/0 GPUs
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                        status       iter     total time (s)     ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | PPO_OligopolyMarket_121a4_00000   RUNNING         8            258.128   8192    42913.8                89245.7               -20748.8                   80                     15 |
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# Trial status: 1 RUNNING
# Current time: 2024-05-11 15:40:49. Total running time: 5min 30s
# Logical resource usage: 4.0/4 CPUs, 0/0 GPUs
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                        status       iter     total time (s)     ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | PPO_OligopolyMarket_121a4_00000   RUNNING         9            292.252   9216    55034.9                 113611               -10434.5                   80                     12 |
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# Trial status: 1 RUNNING
# Current time: 2024-05-11 15:41:19. Total running time: 6min 0s
# Logical resource usage: 4.0/4 CPUs, 0/0 GPUs
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                        status       iter     total time (s)     ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | PPO_OligopolyMarket_121a4_00000   RUNNING         9            292.252   9216    55034.9                 113611               -10434.5                   80                     12 |
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# Trial status: 1 RUNNING
# Current time: 2024-05-11 15:41:49. Total running time: 6min 30s
# Logical resource usage: 4.0/4 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                        status       iter     total time (s)      ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | PPO_OligopolyMarket_121a4_00000   RUNNING        10            328.699   10240    64472.9                 123393                9278.75                   80                     12 |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# Trial status: 1 RUNNING
# Current time: 2024-05-11 15:42:19. Total running time: 7min 0s
# Logical resource usage: 4.0/4 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                        status       iter     total time (s)      ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | PPO_OligopolyMarket_121a4_00000   RUNNING        11            360.875   11264    73037.6                 123393                17106.8                   80                     13 |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# Trial status: 1 RUNNING
# Current time: 2024-05-11 15:42:49. Total running time: 7min 30s
# Logical resource usage: 4.0/4 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                        status       iter     total time (s)      ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | PPO_OligopolyMarket_121a4_00000   RUNNING        12            393.892   12288    83423.3                 132055                33430.2                   80                     14 |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# Trial status: 1 RUNNING
# Current time: 2024-05-11 15:43:19. Total running time: 8min 0s
# Logical resource usage: 4.0/4 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                        status       iter     total time (s)      ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | PPO_OligopolyMarket_121a4_00000   RUNNING        13             425.89   13312    90545.1                 132055                45839.5                   80                     12 |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# Trial status: 1 RUNNING
# Current time: 2024-05-11 15:43:49. Total running time: 8min 30s
# Logical resource usage: 4.0/4 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                        status       iter     total time (s)      ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | PPO_OligopolyMarket_121a4_00000   RUNNING        14             457.08   14336    97665.7                 145798                53533.2                   80                     12 |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# Trial status: 1 RUNNING
# Current time: 2024-05-11 15:44:19. Total running time: 9min 1s
# Logical resource usage: 4.0/4 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                        status       iter     total time (s)      ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | PPO_OligopolyMarket_121a4_00000   RUNNING        15            488.961   15360     105829                 145798                68806.3                   80                     13 |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# Trial status: 1 RUNNING
# Current time: 2024-05-11 15:44:49. Total running time: 9min 31s
# Logical resource usage: 4.0/4 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                        status       iter     total time (s)      ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | PPO_OligopolyMarket_121a4_00000   RUNNING        16             520.95   16384     114258                 155037                72355.1                   80                     14 |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# Trial status: 1 RUNNING
# Current time: 2024-05-11 15:45:19. Total running time: 10min 1s
# Logical resource usage: 4.0/4 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                        status       iter     total time (s)      ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | PPO_OligopolyMarket_121a4_00000   RUNNING        17            555.142   17408     119903                 155037                72355.1                   80                     12 |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# Trial status: 1 RUNNING
# Current time: 2024-05-11 15:45:49. Total running time: 10min 31s
# Logical resource usage: 4.0/4 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                        status       iter     total time (s)      ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | PPO_OligopolyMarket_121a4_00000   RUNNING        18            586.356   18432     125688                 156903                85116.1                   80                     12 |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# Trial status: 1 RUNNING
# Current time: 2024-05-11 15:46:19. Total running time: 11min 1s
# Logical resource usage: 4.0/4 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                        status       iter     total time (s)      ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | PPO_OligopolyMarket_121a4_00000   RUNNING        19             617.66   19456     130689                 156903                92489.3                   80                     13 |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# Trial status: 1 RUNNING
# Current time: 2024-05-11 15:46:49. Total running time: 11min 31s
# Logical resource usage: 4.0/4 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                        status       iter     total time (s)      ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | PPO_OligopolyMarket_121a4_00000   RUNNING        20            649.365   20480     135413                 156903                94733.1                   80                     14 |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# Trial status: 1 RUNNING
# Current time: 2024-05-11 15:47:19. Total running time: 12min 1s
# Logical resource usage: 4.0/4 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                        status       iter     total time (s)      ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | PPO_OligopolyMarket_121a4_00000   RUNNING        21            681.521   21504     139243                 162391                 110684                   80                     12 |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# Trial status: 1 RUNNING
# Current time: 2024-05-11 15:47:49. Total running time: 12min 31s
# Logical resource usage: 4.0/4 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                        status       iter     total time (s)      ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | PPO_OligopolyMarket_121a4_00000   RUNNING        21            681.521   21504     139243                 162391                 110684                   80                     12 |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# Trial status: 1 RUNNING
# Current time: 2024-05-11 15:48:19. Total running time: 13min 1s
# Logical resource usage: 4.0/4 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                        status       iter     total time (s)      ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# ...
# | PPO_OligopolyMarket_121a4_00000   RUNNING        91            2945.87   93184     217297                 229764                 205474                   80                     13 |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# Trial status: 1 RUNNING
# Current time: 2024-05-11 16:25:53. Total running time: 50min 35s
# Logical resource usage: 4.0/4 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                        status       iter     total time (s)      ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | PPO_OligopolyMarket_121a4_00000   RUNNING        92            2980.38   94208     215572                 229660                 205474                   80                     14 |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# Trial status: 1 RUNNING
# Current time: 2024-05-11 16:26:23. Total running time: 51min 5s
# Logical resource usage: 4.0/4 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                        status       iter     total time (s)      ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | PPO_OligopolyMarket_121a4_00000   RUNNING        93            3012.74   95232     214405                 226164                 205474                   80                     12 |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# Trial status: 1 RUNNING
# Current time: 2024-05-11 16:26:53. Total running time: 51min 35s
# Logical resource usage: 4.0/4 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                        status       iter     total time (s)      ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | PPO_OligopolyMarket_121a4_00000   RUNNING        94            3045.13   96256     213696                 222563                 205474                   80                     12 |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# Trial status: 1 RUNNING
# Current time: 2024-05-11 16:27:23. Total running time: 52min 5s
# Logical resource usage: 4.0/4 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                        status       iter     total time (s)      ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | PPO_OligopolyMarket_121a4_00000   RUNNING        95            3078.27   97280     213663                 223097                 205474                   80                     13 |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# Trial status: 1 RUNNING
# Current time: 2024-05-11 16:27:53. Total running time: 52min 35s
# Logical resource usage: 4.0/4 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                        status       iter     total time (s)      ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | PPO_OligopolyMarket_121a4_00000   RUNNING        96            3110.26   98304     213616                 223097                 205474                   80                     14 |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# Trial status: 1 RUNNING
# Current time: 2024-05-11 16:28:24. Total running time: 53min 5s
# Logical resource usage: 4.0/4 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                        status       iter     total time (s)      ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | PPO_OligopolyMarket_121a4_00000   RUNNING        96            3110.26   98304     213616                 223097                 205474                   80                     14 |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# Trial status: 1 RUNNING
# Current time: 2024-05-11 16:28:54. Total running time: 53min 35s
# Logical resource usage: 4.0/4 CPUs, 0/0 GPUs
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                        status       iter     total time (s)      ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | PPO_OligopolyMarket_121a4_00000   RUNNING        97            3142.17   99328     213333                 223097                 205474                   80                     12 |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
#
# Trial PPO_OligopolyMarket_121a4_00000 completed after 98 iterations at 2024-05-11 16:28:57. Total running time: 53min 38s
# +---------------------------------------------------------+
# | Trial PPO_OligopolyMarket_121a4_00000 result            |
# +---------------------------------------------------------+
# | episodes_total                                     1252 |
# | num_env_steps_sampled                            100352 |
# | num_env_steps_trained                                 0 |
# | sampler_results/episode_len_mean                     80 |
# | sampler_results/episode_reward_mean              213226 |
# +---------------------------------------------------------+
#
# Trial status: 1 TERMINATED
# Current time: 2024-05-11 16:28:57. Total running time: 53min 39s
# Logical resource usage: 4.0/4 CPUs, 0/0 GPUs
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                        status         iter     total time (s)       ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | PPO_OligopolyMarket_121a4_00000   TERMINATED       98            3173.92   100352     213226                 223097                 205290                   80                     12 |
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# (PPO pid=136723) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/root/ray_results/PPO_2024-05-11_15-35-18/PPO_OligopolyMarket_121a4_00000_0_2024-05-11_15-35-18/checkpoint_000000)
# (pid=136827) /usr/local/lib/python3.10/dist-packages/tensorflow_probability/python/__init__.py:57: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
# (pid=136827)   if (distutils.version.LooseVersion(tf.__version__) <
# (PPO pid=136723) /usr/local/lib/python3.10/dist-packages/ray/rllib/connectors/agent/obs_preproc.py:40: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead. [repeated 9x across cluster]
# (PPO pid=136723)   prep = cls(observation_space, options) [repeated 3x across cluster]
# (PPO pid=136723) 2024-05-11 15:35:54,076	WARNING algorithm_config.py:2578 -- Setting `exploration_config={}` because you set `_enable_rl_module_api=True`. When RLModule API are enabled, exploration_config can not be set. If you want to implement custom exploration behaviour, please modify the `forward_exploration` method of the RLModule at hand. On configs that have a default exploration config, this must be done with `config.exploration_config={}`. [repeated 6x across cluster]
# (PPO pid=136723)   _, shape = ModelCatalog.get_action_shape( [repeated 3x across cluster]
# (PPO pid=136723)   self._preprocessor = get_preprocessor(obs_space)( [repeated 3x across cluster]
# (PPO pid=136723) 2024-05-11 15:35:54,062	WARNING deprecation.py:50 -- DeprecationWarning: `ValueNetworkMixin` has been deprecated. This will raise an error in the future!
# (PPO pid=136723) 2024-05-11 15:35:54,063	WARNING deprecation.py:50 -- DeprecationWarning: `LearningRateSchedule` has been deprecated. This will raise an error in the future!
# (PPO pid=136723) 2024-05-11 15:35:54,063	WARNING deprecation.py:50 -- DeprecationWarning: `EntropyCoeffSchedule` has been deprecated. This will raise an error in the future!
# (PPO pid=136723) 2024-05-11 15:35:54,063	WARNING deprecation.py:50 -- DeprecationWarning: `KLCoeffMixin` has been deprecated. This will raise an error in the future!
# ResultGrid<[
#   Result(
#     metrics={'custom_metrics': {}, 'episode_media': {}, 'info': {'learner': {'__all__': {'num_agent_steps_trained': 256.0, 'num_env_steps_trained': 4096.0, 'total_loss': 19.72504282196363}, 'policy_firm_0': {'total_loss': 19.72504282196363, 'policy_loss': 0.0020325454126577823, 'vf_loss': 9.936523481210072, 'vf_loss_unclipped': 374327724.0, 'vf_explained_var': -1.679609219233195e-06, 'entropy': 0.13192211257410236, 'mean_kl_loss': 0.008923660598657079, 'default_optimizer_lr': 5.0000000000000016e-05, 'curr_lr': 5e-05, 'curr_entropy_coeff': 0.0, 'curr_kl_coeff': 0.45000001788139343}, 'policy_firm_ex': {'total_loss': 9.782471082607906, 'policy_loss': -0.020538019388914107, 'vf_loss': 9.794921969374021, 'vf_loss_unclipped': 91016179.35833333, 'vf_explained_var': -3.38988999525706e-06, 'entropy': 0.4793036703020334, 'mean_kl_loss': 0.010649360318529944, 'default_optimizer_lr': 5.0000000000000016e-05, 'curr_lr': 5e-05, 'curr_entropy_coeff': 0.0, 'curr_kl_coeff': 0.7593750357627869}}, 'num_env_steps_sampled': 100352, 'num_env_steps_trained': 0, 'num_agent_steps_sampled': 501760, 'num_agent_steps_trained': 0}, 'sampler_results': {'episode_reward_max': 223097.29657777346, 'episode_reward_min': 205289.83664575493, 'episode_reward_mean': 213226.129705744, 'episode_len_mean': 80.0, 'episode_media': {}, 'episodes_this_iter': 12, 'policy_reward_min': {'policy_firm_0': 36390.86217462796, 'policy_firm_ex': 15649.981495417935}, 'policy_reward_max': {'policy_firm_0': 60689.33972544756, 'policy_firm_ex': 29703.37679980134}, 'policy_reward_mean': {'policy_firm_0': 47808.05939936292, 'policy_firm_ex': 21993.892108292308}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [208311.3114822277, 207474.26559915944, 218562.89687542006, 209246.13986434904, 211396.5941447185, 211202.12283263417, 211529.5768625828, 205735.52860935061, 208037.32477899813, 205474.48089024628, 212884.3697608473, 212342.9742722553, 210838.6514962862, 212405.38801919972, 207893.22461523802, 215712.39346805372, 209154.8106103639, 212590.2791049008, 209740.88078732128, 206787.07492679593, 208373.49322788836, 210580.9546094796, 205966.5446769651, 210547.90565718606, 210695.42116531602, 218439.63524062655, 211733.7501442386, 216731.06013555464, 210844.55696054056, 208739.71535105834, 216023.9939923941, 210468.62167803047, 211868.49321297428, 215024.77316018526, 217391.59787974, 209896.05948833795, 213470.8878262617, 213963.93842012013, 210577.5965657257, 209006.06083800737, 216231.78437695242, 218063.32449031805, 209570.20933556455, 214397.442240923, 215721.67304336926, 212698.12113722297, 217565.3428156646, 218261.59063570303, 216986.6029593701, 213313.4978582664, 223097.29657777346, 218162.63709228943, 217265.4516849106, 217688.10859162398, 212300.33007794918, 220448.625508092, 214927.38132096303, 214184.57223464607, 214371.9739489555, 216940.73122515593, 218491.53677170104, 218493.46359587045, 217950.75298961723, 213398.02763241116, 218592.30060557558, 216644.47915750832, 216415.8654132355, 211055.4121529457, 218897.20810678825, 214899.6281352611, 216042.5275018665, 212581.36003331648, 214179.50318929864, 214374.99140464372, 215369.76282731557, 216150.546557024, 209921.1238072621, 214610.75165193633, 214428.40527076568, 211256.56959540868, 209855.6834169497, 213359.09595544072, 219225.1395215487, 212102.0863675819, 215037.15611190494, 210500.68670385546, 217020.00626580324, 210758.80870925746, 212023.96758229545, 208474.11451724372, 205289.83664575493, 209893.4723896091, 216845.5640264072, 212094.66868479725, 210716.36066583873, 216224.80925119182, 212916.7820231036, 210012.8545838864, 214508.4272816219, 212137.1870832671], 'episode_lengths': [80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80, 80,  ...
#     path='/root/ray_results/PPO_2024-05-11_15-35-18/PPO_OligopolyMarket_121a4_00000_0_2024-05-11_15-35-18',
#     filesystem='local',
#     checkpoint=Checkpoint(filesystem=local, path=/root/ray_results/PPO_2024-05-11_15-35-18/PPO_OligopolyMarket_121a4_00000_0_2024-05-11_15-35-18/checkpoint_000000)
#   )
# ]>

# %%
algo_firm_x = Algorithm.from_checkpoint("/root/ray_results/PPO_2024-05-11_15-35-18/PPO_OligopolyMarket_121a4_00000_0_2024-05-11_15-35-18/checkpoint_000000")
# Out:
# 2024-05-11 16:29:40,951	WARNING algorithm_config.py:2578 -- Setting `exploration_config={}` because you set `_enable_rl_module_api=True`. When RLModule API are enabled, exploration_config can not be set. If you want to implement custom exploration behaviour, please modify the `forward_exploration` method of the RLModule at hand. On configs that have a default exploration config, this must be done with `config.exploration_config={}`.
# 2024-05-11 16:29:40,964	WARNING algorithm_config.py:2578 -- Setting `exploration_config={}` because you set `_enable_rl_module_api=True`. When RLModule API are enabled, exploration_config can not be set. If you want to implement custom exploration behaviour, please modify the `forward_exploration` method of the RLModule at hand. On configs that have a default exploration config, this must be done with `config.exploration_config={}`.
# /usr/local/lib/python3.10/dist-packages/ray/rllib/algorithms/algorithm.py:484: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# `UnifiedLogger` will be removed in Ray 2.7.
#   return UnifiedLogger(config, logdir, loggers=None)
# /usr/local/lib/python3.10/dist-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `JsonLogger interface is deprecated in favor of the `ray.tune.json.JsonLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /usr/local/lib/python3.10/dist-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `CSVLogger interface is deprecated in favor of the `ray.tune.csv.CSVLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /usr/local/lib/python3.10/dist-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `TBXLogger interface is deprecated in favor of the `ray.tune.tensorboardx.TBXLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# (pid=149821) /usr/local/lib/python3.10/dist-packages/tensorflow_probability/python/__init__.py:57: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
# (pid=149821)   if (distutils.version.LooseVersion(tf.__version__) <
# (pid=149821) DeprecationWarning: `DirectStepOptimizer` has been deprecated. This will raise an error in the future!
# (RolloutWorker pid=149821) /usr/local/lib/python3.10/dist-packages/ray/rllib/models/catalog.py:786: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
# (RolloutWorker pid=149821)   prep = cls(observation_space, options)
# (RolloutWorker pid=149821) 2024-05-11 16:30:05,888	WARNING algorithm_config.py:2578 -- Setting `exploration_config={}` because you set `_enable_rl_module_api=True`. When RLModule API are enabled, exploration_config can not be set. If you want to implement custom exploration behaviour, please modify the `forward_exploration` method of the RLModule at hand. On configs that have a default exploration config, this must be done with `config.exploration_config={}`.
# (RolloutWorker pid=149821) /usr/local/lib/python3.10/dist-packages/ray/rllib/policy/policy.py:1732: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
# (RolloutWorker pid=149821)   _, shape = ModelCatalog.get_action_shape(
# (RolloutWorker pid=149821) 2024-05-11 16:30:05,944	WARNING algorithm_config.py:2578 -- Setting `exploration_config={}` because you set `_enable_rl_module_api=True`. When RLModule API are enabled, exploration_config can not be set. If you want to implement custom exploration behaviour, please modify the `forward_exploration` method of the RLModule at hand. On configs that have a default exploration config, this must be done with `config.exploration_config={}`.
# (RolloutWorker pid=149821) /usr/local/lib/python3.10/dist-packages/ray/rllib/connectors/agent/obs_preproc.py:40: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
# (RolloutWorker pid=149821)   self._preprocessor = get_preprocessor(obs_space)(
# (RolloutWorker pid=149820) 2024-05-11 16:30:07,097	WARNING deprecation.py:50 -- DeprecationWarning: `ValueNetworkMixin` has been deprecated. This will raise an error in the future!
# (RolloutWorker pid=149820) 2024-05-11 16:30:07,097	WARNING deprecation.py:50 -- DeprecationWarning: `LearningRateSchedule` has been deprecated. This will raise an error in the future!
# (RolloutWorker pid=149820) 2024-05-11 16:30:07,097	WARNING deprecation.py:50 -- DeprecationWarning: `EntropyCoeffSchedule` has been deprecated. This will raise an error in the future!
# (RolloutWorker pid=149820) 2024-05-11 16:30:07,097	WARNING deprecation.py:50 -- DeprecationWarning: `KLCoeffMixin` has been deprecated. This will raise an error in the future!
# /usr/local/lib/python3.10/dist-packages/ray/rllib/models/catalog.py:786: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   prep = cls(observation_space, options)
# 2024-05-11 16:30:07,192	WARNING algorithm_config.py:2578 -- Setting `exploration_config={}` because you set `_enable_rl_module_api=True`. When RLModule API are enabled, exploration_config can not be set. If you want to implement custom exploration behaviour, please modify the `forward_exploration` method of the RLModule at hand. On configs that have a default exploration config, this must be done with `config.exploration_config={}`.
# /usr/local/lib/python3.10/dist-packages/ray/rllib/policy/policy.py:1732: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   _, shape = ModelCatalog.get_action_shape(
# 2024-05-11 16:30:07,219	WARNING algorithm_config.py:2578 -- Setting `exploration_config={}` because you set `_enable_rl_module_api=True`. When RLModule API are enabled, exploration_config can not be set. If you want to implement custom exploration behaviour, please modify the `forward_exploration` method of the RLModule at hand. On configs that have a default exploration config, this must be done with `config.exploration_config={}`.
# /usr/local/lib/python3.10/dist-packages/ray/rllib/connectors/agent/obs_preproc.py:40: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   self._preprocessor = get_preprocessor(obs_space)(
# 2024-05-11 16:30:07,296	INFO trainable.py:188 -- Trainable.setup took 26.278 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2024-05-11 16:30:07,300	WARNING util.py:68 -- Install gputil for GPU system monitoring.
# (RolloutWorker pid=149852) /usr/local/lib/python3.10/dist-packages/ray/rllib/connectors/agent/obs_preproc.py:40: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
# (RolloutWorker pid=149852)   self._preprocessor = get_preprocessor(obs_space)(
# (RolloutWorker pid=149852) /usr/local/lib/python3.10/dist-packages/ray/rllib/connectors/agent/obs_preproc.py:40: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
# (RolloutWorker pid=149852)   self._preprocessor = get_preprocessor(obs_space)(

# %%
algo_firm_x.save("firm_x_pricing_model_checkpoint")
# Out:
# TrainingResult(checkpoint=Checkpoint(filesystem=local, path=firm_x_pricing_model_checkpoint), metrics={})

# %% [markdown]
# ##Chech Which Model Works Best
#
# > Add blockquote

# %%
strats = ['sym','sym','sym','sym','firm_x']
MAX_PERIODS = 100  # max number of steps per episode
num_simulations = 1  # Number of simulations to run

env = OligopolyMarket()
data = []
reward_history = []
for i in range(num_simulations):
    obs, info = env.reset()
    terminated = {}
    terminated["__all__"] = False
    steps = 0

    # Run an episode
    while not terminated["__all__"]:
        actions = {}
        for i, agent in enumerate(agent_ids):
            if strats[i] == 'asym':
              algo = algo_asym
              policies = asym_policies
            elif strats[i] == 'sym':
              algo = algo_sym
              policies = sym_policies
            elif strats[i] == 'firm_x':
              algo = algo_firm_x
              policies = exploit_policies
            a = algo.compute_single_action(
                observation=obs[agent],
                policy_id=policies[agent],
            )
            actions[agent] = a
        prev_obs = obs
        obs, reward, terminated, truncated, info = env.step(actions)
        steps += 1
        rewards.append(reward)

[sum(rew[agent] for rew in rewards) for agent in env._agent_ids]
# Out:
# [7868805.483309196,
#  7701378.075780671,
#  7981175.060317067,
#  7866457.872416034,
#  7647893.961516673]

# %%
sym_policies
# Out:
# {'firm_0': 'policy_firm_0',
#  'firm_1': 'policy_firm_0',
#  'firm_2': 'policy_firm_0',
#  'firm_3': 'policy_firm_0',
#  'firm_4': 'policy_firm_0'}

# %%
asym_policies
# Out:
# {'firm_0': 'policy_firm_0',
#  'firm_1': 'policy_firm_1',
#  'firm_2': 'policy_firm_2',
#  'firm_3': 'policy_firm_3',
#  'firm_4': 'policy_firm_4'}

# %%
exploit_policies
# Out:
# {'firm_0': 'policy_firm_0',
#  'firm_1': 'policy_firm_0',
#  'firm_2': 'policy_firm_0',
#  'firm_3': 'policy_firm_0',
#  'firm_4': 'policy_firm_ex'}

# %%
strats = ['asym','asym','asym','asym','firm_x']
MAX_PERIODS = 100  # max number of steps per episode
num_simulations = 1  # Number of simulations to run

env = OligopolyMarket()
data = []
reward_history = []
for i in range(num_simulations):
    obs, info = env.reset()
    terminated = {}
    terminated["__all__"] = False
    steps = 0

    # Run an episode
    while not terminated["__all__"]:
        actions = {}
        for i, agent in enumerate(agent_ids):
            if strats[i] == 'asym':
              algo = algo_asym
              policies = asym_policies
            elif strats[i] == 'sym':
              algo = algo_sym
              policies = sym_policies
            elif strats[i] == 'firm_x':
              algo = algo_firm_x
              policies = exploit_policies
            a = algo.compute_single_action(
                observation=obs[agent],
                policy_id=policies[agent],
            )
            actions[agent] = a
        prev_obs = obs
        obs, reward, terminated, truncated, info = env.step(actions)
        steps += 1
        rewards.append(reward)

[sum(rew[agent] for rew in rewards) for agent in env._agent_ids]
# Out:
# [8088503.470230487,
#  7884724.666012604,
#  8219393.389706542,
#  8115864.116610322,
#  7772624.991377154]

# %%
strats = ['sym','sym','sym','sym','sym']
MAX_PERIODS = 100  # max number of steps per episode
num_simulations = 1  # Number of simulations to run

env = OligopolyMarket()
data = []
reward_history = []
for i in range(num_simulations):
    obs, info = env.reset()
    terminated = {}
    terminated["__all__"] = False
    steps = 0

    # Run an episode
    while not terminated["__all__"]:
        actions = {}
        for i, agent in enumerate(agent_ids):
            if strats[i] == 'asym':
              algo = algo_asym
              policies = asym_policies
            elif strats[i] == 'sym':
              algo = algo_sym
              policies = sym_policies
            elif strats[i] == 'firm_x':
              algo = algo_firm_x
              policies = exploit_policies
            a = algo.compute_single_action(
                observation=obs[agent],
                policy_id=policies[agent],
            )
            actions[agent] = a
        prev_obs = obs
        obs, reward, terminated, truncated, info = env.step(actions)
        steps += 1
        rewards.append(reward)

[sum(rew[agent] for rew in rewards) for agent in env._agent_ids]
# Out:
# [8386529.467970644,
#  8196877.75645042,
#  8525609.49879098,
#  8404620.980341293,
#  8055432.451647385]

# %%
strats = ['sym','asym','sym','asym','sym']
MAX_PERIODS = 100  # max number of steps per episode
num_simulations = 1  # Number of simulations to run

env = OligopolyMarket()
data = []
reward_history = []
for i in range(num_simulations):
    obs, info = env.reset()
    terminated = {}
    terminated["__all__"] = False
    steps = 0

    # Run an episode
    while not terminated["__all__"]:
        actions = {}
        for i, agent in enumerate(agent_ids):
            if strats[i] == 'asym':
              algo = algo_asym
              policies = asym_policies
            elif strats[i] == 'sym':
              algo = algo_sym
              policies = sym_policies
            elif strats[i] == 'firm_x':
              algo = algo_firm_x
              policies = exploit_policies
            a = algo.compute_single_action(
                observation=obs[agent],
                policy_id=policies[agent],
            )
            actions[agent] = a
        prev_obs = obs
        obs, reward, terminated, truncated, info = env.step(actions)
        steps += 1
        rewards.append(reward)

[sum(rew[agent] for rew in rewards) for agent in env._agent_ids]
# Out:
# [9732092.177677829,
#  9477876.355834665,
#  10000360.248714957,
#  9841854.452414248,
#  9320810.835670931]

# %%
strats = ['asym','sym','asym','sym','asym']
MAX_PERIODS = 100  # max number of steps per episode
num_simulations = 1  # Number of simulations to run

env = OligopolyMarket()
data = []
reward_history = []
for i in range(num_simulations):
    obs, info = env.reset()
    terminated = {}
    terminated["__all__"] = False
    steps = 0

    # Run an episode
    while not terminated["__all__"]:
        actions = {}
        for i, agent in enumerate(agent_ids):
            if strats[i] == 'asym':
              algo = algo_asym
              policies = asym_policies
            elif strats[i] == 'sym':
              algo = algo_sym
              policies = sym_policies
            elif strats[i] == 'firm_x':
              algo = algo_firm_x
              policies = exploit_policies
            a = algo.compute_single_action(
                observation=obs[agent],
                policy_id=policies[agent],
            )
            actions[agent] = a
        prev_obs = obs
        obs, reward, terminated, truncated, info = env.step(actions)
        steps += 1
        rewards.append(reward)

[sum(rew[agent] for rew in rewards) for agent in env._agent_ids]
# Out:
# [9282728.236783892,
#  9282265.762449646,
#  9527306.937681038,
#  9549422.083357979,
#  8851212.082166031]

# %%
strats = ['sym','sym','asym','sym','sym']
MAX_PERIODS = 1000  # max number of steps per episode
num_simulations = 1  # Number of simulations to run

env = OligopolyMarket()
data = []
reward_history = []
for i in range(num_simulations):
    obs, info = env.reset()
    terminated = {}
    terminated["__all__"] = False
    steps = 0

    # Run an episode
    while not terminated["__all__"]:
        actions = {}
        for i, agent in enumerate(agent_ids):
            if strats[i] == 'asym':
              algo = algo_asym
              policies = asym_policies
            elif strats[i] == 'sym':
              algo = algo_sym
              policies = sym_policies
            elif strats[i] == 'firm_x':
              algo = algo_firm_x
              policies = exploit_policies
            a = algo.compute_single_action(
                observation=obs[agent],
                policy_id=policies[agent],
            )
            actions[agent] = a
        prev_obs = obs
        obs, reward, terminated, truncated, info = env.step(actions)
        steps += 1
        rewards.append(reward)

[sum(rew[agent] for rew in rewards) for agent in env._agent_ids]
# Out:
# [10252252.75328505,
#  9892921.008326327,
#  10374647.888193736,
#  10364021.929887593,
#  9813267.192438247]

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class CustomModel(nn.Module):
    def __init__(self, input_size, output_size):
        super(CustomModel, self).__init__()
        self.fc1 = nn.Linear(input_size, 64)  # Input size to be determined based on observation space
        self.fc2 = nn.Linear(64, 64)
        self.fc3 = nn.Linear(64, output_size)  # Output size to be determined based on action space

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# Define the input size and output size of the neural network based on the observation space and action space
input_size = 5  # Assuming observation space size is 5 for Firm_0
output_size = 2  # Assuming action space size is 2 for Firm_0 (Price and Quantity)

# Instantiate the custom neural network model for Firm_0
custom_model = CustomModel(input_size, output_size)

# %%
# Get the weights of the first layer
weights_fc1 = custom_model.fc1.weight
print("Weights of the first layer:")
print(weights_fc1)

# Get the weights of the second layer
weights_fc2 = custom_model.fc2.weight
print("Weights of the second layer:")
print(weights_fc2)

# Get the weights of the third layer (output layer)
weights_fc3 = custom_model.fc3.weight
print("Weights of the third layer (output layer):")
print(weights_fc3)
# Out:
# Weights of the first layer:
# Parameter containing:
# tensor([[ 0.1888, -0.3615,  0.3525,  0.0848, -0.1149],
#         [ 0.0977, -0.3887,  0.0709,  0.0625, -0.2448],
#         [ 0.3810, -0.0479, -0.3925, -0.2081, -0.3874],
#         [ 0.3313, -0.2189,  0.1930,  0.2802,  0.2810],
#         [ 0.0347, -0.0509,  0.1860, -0.1898,  0.1588],
#         [ 0.0037, -0.2909,  0.4277,  0.4041, -0.0946],
#         [ 0.2006, -0.1853, -0.4374, -0.2616,  0.4161],
#         [-0.1428,  0.4285, -0.2577,  0.0018, -0.3143],
#         [ 0.1251,  0.1332,  0.1848,  0.0267, -0.0420],
#         [ 0.0283,  0.0672,  0.3787, -0.2943,  0.2258],
#         [ 0.4148,  0.4444, -0.2638,  0.1947, -0.0497],
#         [-0.2538,  0.0138, -0.1237,  0.2796, -0.0213],
#         [-0.1229, -0.4378, -0.1529, -0.1545, -0.2967],
#         [ 0.1381, -0.3336, -0.3458, -0.2506,  0.0820],
#         [-0.3352, -0.1835, -0.3241, -0.2992, -0.0797],
#         [ 0.3133, -0.0153,  0.1979, -0.3646, -0.4390],
#         [ 0.1828, -0.4321,  0.0152, -0.0560, -0.3344],
#         [ 0.0080, -0.0628,  0.3575,  0.1473,  0.0383],
#         [-0.1163,  0.2751,  0.1168, -0.0609,  0.2969],
#         [ 0.2340,  0.3343, -0.1668,  0.2706,  0.1516],
#         [-0.0066, -0.3068, -0.3750,  0.3260, -0.0039],
#         [-0.2241, -0.1303,  0.1117, -0.4199,  0.1755],
#         [-0.0415, -0.1433,  0.1970, -0.2074, -0.2329],
#         [ 0.0074, -0.3031,  0.2313, -0.2260,  0.0541],
#         [-0.3319, -0.1250,  0.1227, -0.2086, -0.3863],
#         [-0.2918,  0.3563,  0.2661, -0.1865,  0.3060],
#         [-0.3701, -0.1067,  0.3584,  0.1594,  0.4037],
#         [ 0.4424,  0.3156,  0.4124,  0.4088, -0.3333],
#         [ 0.1324,  0.3315,  0.2881, -0.0886,  0.3328],
#         [-0.1219,  0.1216, -0.2456, -0.2600, -0.3735],
#         [-0.1265, -0.2425, -0.0252, -0.2616,  0.2547],
#         [-0.0191, -0.0374, -0.0734, -0.0035,  0.3680],
#         [-0.3131,  0.1783, -0.1300, -0.1470, -0.2455],
#         [-0.2958, -0.3329, -0.2285,  0.4215,  0.3930],
#         [-0.1024,  0.0669,  0.0126,  0.1587, -0.4300],
#         [ 0.4366, -0.0954, -0.1638, -0.4306,  0.1597],
#         [ 0.3850, -0.1008, -0.3713, -0.4216, -0.0432],
#         [-0.0017,  0.1506, -0.3283, -0.3366,  0.3739],
#         [-0.0796, -0.2160,  0.0654,  0.3271, -0.1902],
#         [ 0.1570, -0.1144,  0.0070,  0.1322, -0.0132],
#         [-0.1916,  0.1242,  0.0688,  0.1719,  0.2564],
#         [-0.1867, -0.0041,  0.1608,  0.1815,  0.3418],
#         [ 0.2366,  0.1423,  0.3445, -0.2318, -0.2521],
#         [-0.3753,  0.2967, -0.2080,  0.3450, -0.4095],
#         [ 0.3161,  0.2571, -0.2241, -0.1312, -0.4066],
#         [ 0.2618,  0.4207,  0.2458,  0.4183,  0.3356],
#         [ 0.0987,  0.3578,  0.4378,  0.2683, -0.0117],
#         [ 0.3059, -0.1314, -0.4107, -0.1835, -0.3358],
#         [-0.3335, -0.2277, -0.0606, -0.4357, -0.2720],
#         [ 0.3510,  0.4120,  0.1134,  0.3267,  0.3758],
#         [-0.0963,  0.2697,  0.3627,  0.0994,  0.1745],
#         [ 0.0961, -0.1397, -0.0230, -0.0903, -0.3902],
#         [ 0.0035,  0.2870,  0.2450,  0.4364,  0.0703],
#         [ 0.4116,  0.0580, -0.2694,  0.3599, -0.1957],
#         [-0.1527, -0.1237, -0.3895,  0.3808,  0.2788],
#         [-0.1429, -0.0023,  0.1524,  0.1386, -0.3746],
#         [-0.1539,  0.2857, -0.3773, -0.0787,  0.0530],
#         [-0.0204,  0.0908,  0.1759,  0.1379,  0.3174],
#         [ 0.1454, -0.2693,  0.3602, -0.0477,  0.3069],
#         [-0.3906,  0.2747,  0.1302,  0.3531, -0.3713],
#         [-0.1645,  0.1186, -0.2286,  0.2150, -0.3944],
#         [-0.3099, -0.0311,  0.2533,  0.1380, -0.3927],
#         [ 0.4237, -0.0033, -0.2117, -0.3576,  0.0583],
#         [-0.1736, -0.3735,  0.0368, -0.3799,  0.2170]], requires_grad=True)
# Weights of the second layer:
# Parameter containing:
# tensor([[ 0.1224, -0.0781, -0.0185,  ...,  0.0706,  0.0088,  0.1013],
#         [ 0.1035,  0.0237, -0.0684,  ..., -0.0452,  0.0531,  0.0884],
#         [-0.0780,  0.0913,  0.0002,  ..., -0.0861, -0.0754,  0.1126],
#         ...,
#         [-0.0723,  0.1005,  0.1149,  ..., -0.0767,  0.0103,  0.0157],
#         [ 0.1233, -0.0246, -0.0029,  ...,  0.0398,  0.0346, -0.0303],
#         [ 0.0460, -0.0506,  0.0844,  ...,  0.0898, -0.0966, -0.0003]],
#        requires_grad=True)
# Weights of the third layer (output layer):
# Parameter containing:
# tensor([[ 0.0807,  0.0992,  0.0415,  0.0774,  0.1148,  0.0931,  0.1108,  0.0131,
#           0.0535,  0.0681,  0.0312, -0.0472,  0.0980,  0.0786, -0.0476, -0.0276,
#          -0.0715, -0.0446, -0.0773,  0.0271,  0.0900,  0.0608,  0.0056,  0.0967,
#           0.0145,  0.0271,  0.0021,  0.0815,  0.0052,  0.0723, -0.0947, -0.1006,
#           0.0600,  0.0217, -0.0182,  0.0545,  0.0001, -0.0214,  0.0864, -0.0312,
#          -0.0213, -0.1051,  0.0119, -0.0219, -0.0614,  0.0966, -0.0983, -0.0029,
#           0.0127,  0.1172, -0.0098, -0.0211, -0.0074,  0.0701,  0.1158,  0.1139,
#          -0.0006, -0.0218, -0.0195, -0.0475, -0.0849, -0.0675,  0.0687,  0.1087],
#         [ 0.0132, -0.0097, -0.0646,  0.0009, -0.1003,  0.0218,  0.0712,  0.0076,
#           0.0062,  0.0356, -0.0936,  0.1123,  0.0934, -0.0862, -0.0621, -0.0575,
#          -0.0624, -0.0482,  0.0860,  0.0439,  0.0447,  0.0972,  0.0575, -0.0811,
#          -0.0608,  0.0947, -0.0322, -0.0439,  0.0510,  0.0964,  0.0998,  0.0796,
#          -0.0831, -0.1010,  0.0813, -0.1075,  0.0921,  0.0954,  0.0454, -0.1079,
#           0.1221,  0.0504,  0.0004,  0.0826, -0.1025, -0.0719,  0.0475, -0.0863,
#           0.0747, -0.0544,  0.0229, -0.0808,  0.0283, -0.0177, -0.0551,  0.0304,
#          -0.0598, -0.0798,  0.0945,  0.0077, -0.0145, -0.0321, -0.1203, -0.0588]],
#        requires_grad=True)

# %% [markdown]
# ##sym_model_pricing = Algorithm.from_checkpoint("/root/ray_results/PPO_2024-05-10_18-30-07/PPO_OligopolyMarket_53cca_00000_0_2024-05-10_18-30-07/checkpoint_000000")
